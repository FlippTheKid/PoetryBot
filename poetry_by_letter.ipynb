# %%
from collections import Counter
from torch.utils.data import Dataset, DataLoader
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
from pathlib import Path
from nltk.corpus import stopwords
import string
import json
import re
import pandas as pd, numpy as np
import matplotlib.pyplot as plt
import os, urllib, itertools, shutil, random
from torch.utils.data import Dataset, DataLoader
from sklearn.metrics import confusion_matrix
import PIL
import torch
from pathlib import Path

# %%
# !unzip Poetry.zip -d myfiles
# Out:
# Archive:  Poetry.zip
#    creating: myfiles/Poetry/
#   inflating: myfiles/Poetry/1.txt
#   inflating: myfiles/Poetry/10.txt
#   inflating: myfiles/Poetry/11.txt
#   inflating: myfiles/Poetry/12.txt
#   inflating: myfiles/Poetry/19th_oct.txt
#   inflating: myfiles/Poetry/22.txt
#   inflating: myfiles/Poetry/23.txt
#   inflating: myfiles/Poetry/25.txt
#   inflating: myfiles/Poetry/3.txt
#   inflating: myfiles/Poetry/33.txt
#   inflating: myfiles/Poetry/4.txt
#   inflating: myfiles/Poetry/5.txt
#   inflating: myfiles/Poetry/6.txt
#   inflating: myfiles/Poetry/7.txt
#   inflating: myfiles/Poetry/8.txt
#   inflating: myfiles/Poetry/9.txt
#   inflating: myfiles/Poetry/about_a_fish.txt
#   inflating: myfiles/Poetry/about_oleg.txt
#   inflating: myfiles/Poetry/alex1.txt
#   inflating: myfiles/Poetry/anchar.txt
#   inflating: myfiles/Poetry/aughtam.txt
#   inflating: myfiles/Poetry/beglets.txt
#   inflating: myfiles/Poetry/blue_mount_kavkaz.txt
#   inflating: myfiles/Poetry/bogatyr1.txt
#   inflating: myfiles/Poetry/bogatyr2.txt
#   inflating: myfiles/Poetry/bogatyr4.txt
#   inflating: myfiles/Poetry/bogatyr5.txt
#   inflating: myfiles/Poetry/borodino.txt
#   inflating: myfiles/Poetry/burya_mgloyu.txt
#   inflating: myfiles/Poetry/chaadaev.txt
#   inflating: myfiles/Poetry/chudnoe_mgnovenie.txt
#   inflating: myfiles/Poetry/demon1.txt
#   inflating: myfiles/Poetry/demon10.txt
#   inflating: myfiles/Poetry/demon11.txt
#   inflating: myfiles/Poetry/demon12.txt
#   inflating: myfiles/Poetry/demon13.txt
#   inflating: myfiles/Poetry/demon14.txt
#   inflating: myfiles/Poetry/demon15.txt
#   inflating: myfiles/Poetry/demon16.txt
#   inflating: myfiles/Poetry/demon2.txt
#   inflating: myfiles/Poetry/demon3.txt
#   inflating: myfiles/Poetry/demon4.txt
#   inflating: myfiles/Poetry/demon5.txt
#   inflating: myfiles/Poetry/demon6.txt
#   inflating: myfiles/Poetry/demon7.txt
#   inflating: myfiles/Poetry/demon8.txt
#   inflating: myfiles/Poetry/demon9.txt
#   inflating: myfiles/Poetry/deth.txt
#   inflating: myfiles/Poetry/dlya_chego.txt
#   inflating: myfiles/Poetry/duma.txt
#   inflating: myfiles/Poetry/dva_velikana.txt
#   inflating: myfiles/Poetry/est_rechi.txt
#   inflating: myfiles/Poetry/from_paris.txt
#   inflating: myfiles/Poetry/go_alone_on_a_road.txt
#   inflating: myfiles/Poetry/groza.txt
#   inflating: myfiles/Poetry/is_gete.txt
#   inflating: myfiles/Poetry/i_skuchno_i_grustno.txt
#   inflating: myfiles/Poetry/k.txt
#   inflating: myfiles/Poetry/kak_chasto.txt
#   inflating: myfiles/Poetry/kavkazu.txt
#   inflating: myfiles/Poetry/kazachya_kolybelnaya.txt
#   inflating: myfiles/Poetry/klevetnikam.txt
#   inflating: myfiles/Poetry/kney.txt
#   inflating: myfiles/Poetry/k_sebe.txt
#   inflating: myfiles/Poetry/listok.txt
#   inflating: myfiles/Poetry/lukomorye.txt
#   inflating: myfiles/Poetry/lyubili.txt
#   inflating: myfiles/Poetry/med1.txt
#   inflating: myfiles/Poetry/med2.txt
#   inflating: myfiles/Poetry/med3.txt
#   inflating: myfiles/Poetry/molitva.txt
#   inflating: myfiles/Poetry/moroz_i_solnce.txt
#   inflating: myfiles/Poetry/moy_demon.txt
#   inflating: myfiles/Poetry/mziri.txt
#   inflating: myfiles/Poetry/na_severe_dikom.txt
#   inflating: myfiles/Poetry/nemytaya_rossiya.txt
#   inflating: myfiles/Poetry/ne_obvinyay.txt
#   inflating: myfiles/Poetry/ne_tebya.txt
#   inflating: myfiles/Poetry/ne_unizhus.txt
#   inflating: myfiles/Poetry/nishiy.txt
#   inflating: myfiles/Poetry/niva.txt
#   inflating: myfiles/Poetry/no_love.txt
#   inflating: myfiles/Poetry/nyane.txt
#   inflating: myfiles/Poetry/odinochestvo.txt
#   inflating: myfiles/Poetry/orsha.txt
#   inflating: myfiles/Poetry/osen.txt
#   inflating: myfiles/Poetry/o_soltane.txt
#   inflating: myfiles/Poetry/parus.txt
#   inflating: myfiles/Poetry/poet.txt
#   inflating: myfiles/Poetry/poltava1.txt
#   inflating: myfiles/Poetry/poltava2.txt
#   inflating: myfiles/Poetry/poltava3.txt
#   inflating: myfiles/Poetry/poltava4.txt
#   inflating: myfiles/Poetry/poltava5.txt
#   inflating: myfiles/Poetry/prorok (2).txt
#   inflating: myfiles/Poetry/prorok.txt
#   inflating: myfiles/Poetry/rodina.txt
#   inflating: myfiles/Poetry/romance.txt
#   inflating: myfiles/Poetry/sea_quinn.txt
#   inflating: myfiles/Poetry/smert_poeta.txt
#   inflating: myfiles/Poetry/son_v_dagestane.txt
#   inflating: myfiles/Poetry/sun.txt
#   inflating: myfiles/Poetry/sun_of_fall.txt
#   inflating: myfiles/Poetry/thanksgiving.txt
#   inflating: myfiles/Poetry/the_more.txt
#   inflating: myfiles/Poetry/to_child.txt
#   inflating: myfiles/Poetry/to_onegin.txt
#   inflating: myfiles/Poetry/tuchi.txt
#   inflating: myfiles/Poetry/two_bros.txt
#   inflating: myfiles/Poetry/utes.txt
#   inflating: myfiles/Poetry/uznik.txt
#   inflating: myfiles/Poetry/valerik.txt
#   inflating: myfiles/Poetry/vesna.txt
#   inflating: myfiles/Poetry/vo_glubine_sib_rud.txt
#   inflating: myfiles/Poetry/why.txt
#   inflating: myfiles/Poetry/winter_freeze.txt
#   inflating: myfiles/Poetry/ya_pamyatnik.txt
#   inflating: myfiles/Poetry/ya_vas_lyubil.txt

# %%
# !unzip poems.csv.zip -d myfiles
# Out:
# Archive:  poems.csv.zip
# replace myfiles/poems.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: A
#   inflating: myfiles/poems.csv

# %%
mydf = pd.read_csv("/content/myfiles/poems.csv")

# %%
TRAIN_DIR = Path('/content/myfiles/Poetry/')
files_list = list(TRAIN_DIR.rglob('*.txt'))

# %%
class PoetryDataset(Dataset):
  def __init__(self, files, mode):
    super().__init__()
    self.files = files
    self.mode = mode

    if not os.path.exists("word_to_index.json"):
      self.create_word_to_index_dict()
    with open('word_to_index.json', 'r') as f:
      loaded_dict = json.load(f)
      self.word_to_index_dict = loaded_dict


  def __len__(self):
    return len(self.files)

  def loadtxt(self, file):
    with open(file, 'r', encoding='utf-8') as text:
      content = text.read()
    return content


  def preprocess_for_w2vec(self, content):
      lines = content.splitlines()
      tokens = []
      for line in lines:
          line_tokens = re.findall(r'.|\s', line)
          tokens.extend(line_tokens)
          tokens.append("EOL")
      return tokens

  def create_word_to_index_dict(self):

    word_counter = {}


    for file in self.files:
        content = self.loadtxt(file)
        tokens = self.preprocess_for_w2vec(content)
        for token in tokens:
            if token not in word_counter:
                word_counter[token] = 1
            else:
                word_counter[token] += 1


    word_to_index = {word: idx for idx, (word, _) in enumerate(word_counter.items())}
    word_to_index["PAD"] = len(word_to_index)
    with open('word_to_index.json', 'w') as f:
       json.dump(word_to_index, f)

    return word_to_index


  def __getitem__(self, idx):
      fileee = self.loadtxt(self.files[idx])
      sequence_of_tokens = self.preprocess_for_w2vec(fileee)

      inputs = sequence_of_tokens[:-1]
      targets = sequence_of_tokens[1:]


      sequence_of_indices_input = [self.word_to_index_dict.get(token) for token in inputs]
      sequence_of_indices_target = [self.word_to_index_dict.get(target) for target in targets]

      return {"inputs": torch.tensor(sequence_of_indices_input),
            "targets": torch.tensor(sequence_of_indices_target)}

# %%
train_val_files = list(TRAIN_DIR.rglob('*.txt'))
train_dataset = PoetryDataset(train_val_files, mode='train')

# %%
with open('word_to_index.json', 'r') as f:
    loaded_dict = json.load(f)

# %%
index_to_word = {value: key for key, value in loaded_dict.items()}

# %%
len(loaded_dict)
# Out:
# 118

# %%
def evaluate(model, char_to_idx, idx_to_char, start_text=' ', prediction_len=200, temp=0.3):
    hidden = model.init_hidden()
    idx_input = [char_to_idx[char] for char in start_text]
    train = torch.LongTensor(idx_input).view(-1, 1, 1).to(device)
    predicted_text = start_text

    _, hidden = model(train, hidden)

    inp = train[-1].view(-1, 1, 1)

    for i in range(prediction_len):
        output, hidden = model(inp.to(device), hidden)
        output_logits = output.cpu().data.view(-1)
        p_next = F.softmax(output_logits / temp, dim=-1).detach().cpu().data.numpy()
        top_index = np.random.choice(len(char_to_idx), p=p_next)
        inp = torch.LongTensor([top_index]).view(-1, 1, 1).to(device)
        predicted_char = idx_to_char[top_index]
        if predicted_char == 'EOL':  # Проверка на EOL
            predicted_text += '\n'
        else:
            predicted_text += predicted_char

    return predicted_text

# %%
class PoetryLSTM(nn.Module):
  def __init__(self, input_size, hidden_size, embedding_size, n_layers):
    super(PoetryLSTM, self).__init__()
    self.input_size = input_size
    self.hidden_size = hidden_size
    self.embedding_size = embedding_size
    self.n_layers = n_layers


    self.embedding = nn.Embedding(self.input_size, self.embedding_size)

    self.lstm = nn.LSTM(input_size=self.embedding_size,
                            hidden_size=self.hidden_size,
                            num_layers= self.n_layers)
    self.dropout = nn.Dropout(0.2)

    self.fc_out = nn.Linear(self.hidden_size, self.input_size)

  def forward(self, x, hidden):
      embedded_x = self.embedding(x).squeeze(2)
      lstm_out, (ht0, ct0) = self.lstm(embedded_x, hidden)
      lstm_out = self.dropout(lstm_out)
      linear_layer_out_before_softmax = self.fc_out(lstm_out)

      return linear_layer_out_before_softmax, (ht0, ct0)

  def init_hidden(self, batch_size=1):
      return (torch.zeros(self.n_layers, batch_size, self.hidden_size, requires_grad=True).to(device),
              torch.zeros(self.n_layers, batch_size, self.hidden_size, requires_grad=True).to(device))

# %%
from torch.utils.data import DataLoader
from torch.nn.utils.rnn import pad_sequence

# %%
def custom_collate(batch):
  max_seq_len = 1000
  inputs_batch_list = [item["inputs"] for item in batch]
  targets_batch_list = [item["targets"] for item in batch]
  padded_inputs = pad_sequence(inputs_batch_list, batch_first = True, padding_value = loaded_dict["PAD"])
  padded_targets = pad_sequence(targets_batch_list, batch_first = True, padding_value = loaded_dict["PAD"])
  mask = (padded_targets != loaded_dict["PAD"]).float()
  return {"inputs": padded_inputs[:, :max_seq_len].unsqueeze(-1),
          "targets": padded_targets[:, :max_seq_len].unsqueeze(-1),
          "mask": mask}

# %%
batch_size = 12

# %%
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle = True, collate_fn = custom_collate)

# %%
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')
model = PoetryLSTM(input_size=len(index_to_word), hidden_size=128, embedding_size=128, n_layers=2)
model.to(device)

criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=1e-2, amsgrad=True)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
    optimizer,
    patience=5,
    verbose=True,
    factor=0.5
)

n_epochs = 2000
loss_avg = []

# %%
for epoch in range(n_epochs):
    print(epoch)
    for batch in train_loader:
      model.train()
      train, target = batch["inputs"], batch["targets"]



      train = train.permute(1, 0, 2).to(device)
      target = target.permute(1, 0, 2).to(device)

      train = train.contiguous()
      target = target.contiguous()

      batch_size = train.size(1)

      hidden = model.init_hidden(batch_size)



      output, hidden = model(train, hidden)
      loss = criterion(output.permute(1, 2, 0), target.squeeze(-1).permute(1, 0))

      loss.backward()
      optimizer.step()
      optimizer.zero_grad()

      loss_avg.append(loss.item())
      if len(loss_avg) >= 50:
          mean_loss = np.mean(loss_avg)
          print(f'Loss: {mean_loss}')
          scheduler.step(mean_loss)
          loss_avg = []
          model.eval()
          predicted_text = evaluate(model, loaded_dict, index_to_word)
          print(predicted_text)
# Out:
# Выходные данные были обрезаны до нескольких последних строк (5000).
# 174
# Loss: 0.5429088598489762
#  творенья —
# И долго слава — от сердце глуши трудно.
# И вымолвить хочет на свете
# Ты царевны молодой?
# Я жених ее». — «Постой, ни родит
# Не отдаленный путь сказать свой мучии
# Мечло молво и постигнуть не воз
# 175
# 176
# 177
# 178
# 179
# Loss: 0.5401284652948379
#  анге сердительный полны,
# И над порока меч вести,
# До прочив тоской забавы,
# Как сило пользы видит, ни народ,
# И главы не подобный лесов
# Прекрасно повудного царяй;
# Вот вышет безумных рек.
# Поверьтенья не с
# 180
# 181
# 182
# 183
# 184
# Loss: 0.541507169008255
#  улабою простится,
# Повод ним кого не столбой
# Он давно пришел, когда вас больше не одна.
# Не вижу меня верною ветви лаская;
# С тени скалодный перед напрями мечтам.
# Они польность сладостется в сердца таин…
# 185
# 186
# 187
# 188
# 189
# Loss: 0.5289301067590714
#  анке волны,
# Так мучине пропал, пылая обман…
# Шуми, шуми по небу
# Стобою далекой прости!
# Согреты под собой в тихо мне,
# И вижу мило прибрасной любовью,
# Так тоспойся подобный небе молвил.
# На берег разделая
# 190
# 191
# 192
# 193
# 194
# Loss: 0.5244905877113343
#  авкам печальный
# Стоятся пристушной угать.
# Загоравонный над ветерка,
# И ты мой собрании свой верном страстяте
# Спешь, будто баяских пладый,
# Под завистливой стоит свою потеры.
# В груди и мою раз востокою
# О
# 195
# 196
# 197
# 198
# 199
# Loss: 0.5064461648464202
#  улонию,
# И знов, ни нем нет!
# Себя любить, как он времяный
# И славе с томительный над вас тихонько,
# И прошерного солнца, —
# Том лежал в море с мольбой,
# Красавия, зла с набег она
# Из кованьем он грустной;
# С
# 200
# 201
# 202
# 203
# 204
# Loss: 0.5095593452453613
#  улабыя тебя люблю!
# Как тесные свете взглядела старица,
# Лежат послушно я мною толпой,
# Когда странник променевести моя
# И надос сокрованье долина
# Не видал он сужденом потом
# Все приходу с тобою,
# Не пришел
# 205
# 206
# 207
# 208
# 209
# Loss: 0.5089105784893035
#  австих томи он.
# От их всему непрозовый,
# И час обой с топроща мою любовь
# Прель на сердце было сердца людей.
# Его приживый в невеставуй,
# Теперь он собой на просторе.
# В надежной селеющий стон
# Невы не зала
# 210
# 211
# 212
# 213
# 214
# Loss: 0.501614641547203
#  австих довольный родит.
# Есть стало привет ударяя
# В дерзивет моей прах, предадим
# На стремлина он веселых нелюбим,
# И ската мне пройдет стоил свободные листолькая нежной;
# Их взолос и просторе».
# Воротился
# 215
# 216
# 217
# 218
# 219
# Loss: 0.48465314507484436
#  авкам ее,
# И не устала с умолки, —
# Ты на свете всех милее,
# Всех румяней и белее,
# И тихо в стране далекой,
# Вотся ночной высокой бесполе он в бурями.
# В те кареволи вышна да дале на свете
# Ты гордиеся меня
# 220
# 221
# 222
# 223
# 224
# Loss: 0.5001494628190994
#  увятей прекрасной
# Его ульго семью платы все,
# И не пришел, коварное спустыне.
# Волненье братыми свой ночлег,
# По кровь иль передо ночь прошерного ленят.
# И мотвые верь почерный перетен;
# Не ведел удар облу
# 225
# 226
# 227
# 228
# 229
# Loss: 0.49763024926185606
#  авкам мелчанье,
# И не одну сама своей летою окруженых
# И преданьях берега.
# Но не соседняет просит,
# То время на простой взор молодутья
# На грустный под небесами:
# Убит! верная поте своей
# Королевечные полче
# 230
# 231
# 232
# 233
# 234
# Loss: 0.48186170995235444
#  увесниц,
# Выпьем с горя горяя;
# В груди раздешь, молчальный Древой.
# В день и кормцы нас тебя мгле,
# И песни, коварное страданье.
# А Румянуют сердца не дал бог:
# Пас самер печали врагом,
# Я вас богат внемел
# 235
# 236
# 237
# 238
# 239
# Loss: 0.47232791543006897
#  авцар я целый день;
# И к моей несчастной душой
# Она забытой серебра
# И на праник в страхе,
# Базу дорого, неним внимали;
# В тем мне тебя равнось будет
# В отдушный гордуго: бы жизнь;
# И в стремела там природы
# 240
# 241
# 242
# 243
# 244
# Loss: 0.4597728806734085
#  улыбкой седой,
# И так тревога, где же друзьей.
# И если зла душою скалою вечно и пристанье.
# Они лишь виной, на дорогу
# Не отдала без надежде,
# И не оставит, не привет он властью радостной славу.
# Устары мне
# 245
# 246
# 247
# 248
# 249
# Loss: 0.4616372537612915
#  увеснисть мой грусть,
# Голуденных струйною день, — и тебя он друг друга,
# Без под них струя свободный судьбою,
# Рокого он веселых дней,
# Толпянь, и собой, мне долгет.
# Не виданья не нахваньем и томительце
#
# 250
# 251
# 252
# 253
# 254
# Loss: 0.46494427263736726
#  янно угреты,
# Одна в серную моей,
# Выпьем с горя: где же черты.
# В глуши вольностью солнца робком
# Чубовь желтые сердит
# Сердито простилась
# И под сказал ей на свобода,
# В поревно вод бежит,
# На весной листы
# 255
# 256
# 257
# 258
# 259
# Loss: 0.459683900475502
#  анге в путной груди глуботет;
# Там надпокослит гордого друг друга,
# И волно; дымился он жене:
# Давно в будто с умолкий потом
# Пред ним сила, белые стоит от забава.
# С тех пор в стремить у него мир,
# Как в с
# 260
# 261
# 262
# 263
# 264
# Loss: 0.4562792730331421
#  ям — земли отвара,
# И ты с ними степь отчизне со мной.
# Она право ни блаженстве на просторе.
# Прозой воле он славу то не знаю,
# Добычалься мнего благорогой
# Нево лишь то ночь, имением душой
# На не славы слы
# 265
# 266
# 267
# 268
# 269
# Loss: 0.4588455933332443
#  авкам поле он меня,
# Он стоит в сердце глуши служить не мог!
# Во-первых потому, что много,
# И не грозил он ветвей
# Идет природы бес соковью
# Он сверкнул он он ветер рукой
# Навскакой и чуде мою.
# Забыл он в г
# 270
# 271
# 272
# 273
# 274
# Loss: 0.4575830799341202
#  увесь с кинят;
# Но кительными солнце,
# Лета, м так светлый в небесные,
# На кровать слоновой как страстей
# И муза тебя с нит бездельные странники!
# Темно презренит — и собой;
# Когда поморивил он сердце,
# Как
# 275
# 276
# 277
# 278
# 279
# Loss: 0.4593533962965012
#  анге дар ей
# Свижу велее он в пустыне,
# Осенитель гордый кинем, да полны весной,
# Еще конь прихотит плясь,
# И за пирует вечные странники!
# Смотрит в ответ: «Неа образом Каказам,
# И глас как нет страстью ста
# 280
# 281
# 282
# 283
# 284
# Loss: 0.4445674616098404
#  авкам печальный
# Волны, полны мечтою девых строей,
# И звезды слушают меня,
# Лучами дружество до ночи,
# И к печальный перед отданая
# Одна в меж темнокого пути;
# Он в страсти стану караван.
# Страданья и просто
# 285
# 286
# 287
# 288
# 289
# Loss: 0.4413495081663132
#  увяне далеканий
# Не боле невеста непонятный,
# И лучший позадинь он и такой
# И на словам на солнце из баблин,
# Как море сердце был честью подзумним
# В позни склонился от нем, то с верною простила,
# И так чув
# 290
# 291
# 292
# 293
# 294
# Loss: 0.43682823061943055
#  авкам;
# В то время на солнце, снег лежит.
# Славы я наш солнышка, постой-теружит!
# И пот на другой томился,
# Кони разных осенник молодой
# Мне долго своей святыня,
# И звон не могу паруит,
# И звездой смиренный
# 295
# 296
# 297
# 298
# 299
# Loss: 0.43493603527545927
#  увяжу говорит.
# 2
# В небесах я страстью сердца молчаньем
# И скрылся дождь в отдавно,
# Всесли говорях на пирин, и встревняй.
# Стану скачуй красов,
# Стихий сиин сомненный судьбою,
# Вопрос, которого не мог ласк
# 300
# 301
# 302
# 303
# 304
# Loss: 0.4332337242364883
#  авкам поле не улыбь,
# И все, сказку верная семе
# Над сонной друживых мородой
# Не оставите водом
# В светлицу дерился девет;
# Там по небу, к моя при друг,
# Свободы праздник молодой
# Минуты верного светло,
# И ск
# 305
# 306
# 307
# 308
# 309
# Loss: 0.43443763375282285
#  авкаю лун
# Из настепник привел нелка, — заводный день,
# Ты друг нас ласком пришленная пролетая,
# Попертам грозного лета,
# Стрешены, пришлец один унылой
# И наглости порывный клюло;
# Всему жились он жене:
# Дав
# 310
# 311
# 312
# 313
# 314
# Loss: 0.4269030439853668
#  авкаши,
# Поезурить Перучит.
# Ночь по всеми с вестой,
# На сужном старик не спит;
# Он перед углями рабов
# Иные мечты толпой,
# Но волны не наконец и жаждой простоты,
# Что рочи женил слава — — опчет слава
# Под жи
# 315
# 316
# 317
# 318
# 319
# Loss: 0.4204624062776566
#  юности страстей,
# Но ни жится, быть может, —
# Один, всаден был в глубине.
# С рукой и песни по небу уленеслого
# Припавду, бедный в невозможно.
# И велит! Он думой старых речей.
# Исчто там лес с печей, но пото
# 320
# 321
# 322
# 323
# 324
# Loss: 0.42349810123443604
#  авцал мучесть;
# Что мог бы друга полей,
# Циес скоростью краса и плеся:
# Плесть в страсти станутые радной
# На неволе небесной вышите склонясь,
# Милькомнести порывный двор
# Седой чужи? он и том не безлуют:
# По
# 325
# 326
# 327
# 328
# 329
# Loss: 0.42727730453014373
#  увяны,
# Стару, дели грустно, что же гет меня,
# И часто такой-то помнить конь;
# С долин вольностью летело
# Прездной детствии солнца,
# Кругом шумить нас,
# Что я соломе взгляни, наш век?
# Они тебе за бранный со
# 330
# 331
# 332
# 333
# 334
# Loss: 0.4242207908630371
#  юны. Наше благода,
# И обещая неждой грудь,
# И всю рано презирал знаком,
# Да по знаменье креста,
# И все, права степей волно.
# А братами солнце жгло их звуком
# Уданством упругом, —
# Припам собой лишь взор я те
# 335
# 336
# 337
# 338
# 339
# Loss: 0.4208575874567032
#  увянца любвю ого на облове;
# Страшится ли народовался —
# И б забру недавний простой.
# Они колена преклонивь,
# Не стоит одного седа
# Невеста вольности храня
# На земле и страданья.
# Пока свободою горим,
# Пока с
# 340
# 341
# 342
# 343
# 344
# Loss: 0.42042481899261475
#  авкай,
# С непревнем счастье цепь житило,
# В том желанит песни брани;
# Дуя забава, забве,
# Как на воль пирой свободы,
# Один не знал его ль их своих на обрашена
# Его оставить не страсть,
# Грядущий робсивею вер
# 345
# 346
# 347
# 348
# 349
# Loss: 0.42240554571151734
#  юности,
# Что не оставить нет меня,
# Осасть все, старут меня;
# В берегва в мире нового ветвей,
# И тот же веселой сиявисти моей,
# Выпьем с утра до ночи,
# Туда, сладко вдруг на свете
# Ты царевны моложит.
# В тепе
# 350
# 351
# 352
# 353
# 354
# Loss: 0.30666029185056687
#  увяжу дом,
# Звенен в ответ ли в боресь, вьюга плачатся
# Перед жизньем подзутесь, страстей.
# Смиренных струн, быть может, и клюет;
# В теснями лару и мир,
# Когда бегущая чертыря
# В часа поверь тенью следа
# Сед
# 355
# 356
# 357
# 358
# 359
# Loss: 0.2399890375137329
#  увесь в око.
# От изменил прия своего.
# И под полодину староко
# Неленье бойился он он ветер,
# Обиди расстал соседних и горя
# И ветер душа и грудь отрадной.
# Как весело мы небе променять.
# Но невеста молиться,
# 360
# 361
# 362
# 363
# 364
# Loss: 0.2224370700120926
#  увеж, меня лишь серебрит.
# Ночью муки, и все внуго,
# Илых обольго стекло.
# В краю возвезайтые стеклая
# По всем не знаком своем,
# Как вам страшный в сердце в будущем домой,
# И ветер звонкий голосок!
# На светр
# 365
# 366
# 367
# 368
# 369
# Loss: 0.21039524614810945
#  увяны мучины
# Что ты, как желат;
# Вьюг не встал и слом меня.
# То лони мечтою войной;
# Когда дубровь он и злобно вольной,
# Но пруд уже довольное лицо
# Приятной важностью сияет.
# Чекмень затянутый на просторе.
# 370
# 371
# 372
# 373
# 374
# Loss: 0.20379473209381105
#  увяны муки,
# И ветерствуе мгле тебе —
# И думай, что во дни разлуки,
# В моей изменчивой слово за тронах
# С борок, стал одина
# Нетен разный своей,
# Толпесь в нему стоит меня,
# Вы не простуют для негого долго г
# 375
# 376
# 377
# 378
# 379
# Loss: 0.19924702674150466
#  увянул на родину своей
# Кольцо, наследие царей;
# Он дал ему с тобой страданье
# С Калуша так исколовой
# И сердце в бешеле давно —
# Нет, иль сель у томы порыв,
# Чтоб топким на просторе я ночи,
# Баюшки-баю.
# Сам
# 380
# 381
# 382
# 383
# 384
# Loss: 0.19605566501617433
#  увяны —
# Семтела грядущее —
# И перед устал одном страданье,
# И милый образ во след не даром сол,
# Красавица, безумный
# Не прошлого старик и летена;
# Ск терегния молва, илпуки
# Разбудьть моя подругой быстрые
# 385
# 386
# 387
# 388
# 389
# Loss: 0.19421060711145402
#  улыбкой свой боя:
# Я мысль он и будто за лебенье,
# Как звук ночной в сердце отдала?
# Нет, жены робкие Гаравно.
# Все трепетной мелократись,
# Молитво потомдинский нас воды,
# Ловит солны в ответе страданье,
# И
# 390
# 391
# 392
# 393
# 394
# Loss: 0.19191785633563996
#  авкали высоки…
# Что будут душа моей рукой
# Отмчится повариха:
# «Свет меня пению веселый
# В наш милому вечно своей
# К негорого душой.
# Он шел в ответ стояет с чела,
# Звезда младыми моей друг,
# Влои в погашена.
# 395
# 396
# 397
# 398
# 399
# Loss: 0.18965315639972688
#  увесь с тобой
# Строже от пог упруженым мою родную.
# И вела сердце насменной листокой
# Витал ты друг друга погасненье,
# И для него воскресли вновь
# И божество, и вдохновенья!
# Честь без волненья
# Внимать нево
# 400
# 401
# 402
# 403
# 404
# Loss: 0.18981619894504548
#  улышный град
# С больно поверез очей листочет своей
# Коль, наш гонит он:
# Проведал ей нас тебя мне.
# Зачем же ты меня не любишь?
# Мой друг, несправедлива ты.
# Оставь безумные мечты;
# Ты подозреньем сердце губ
# 405
# 406
# 407
# 408
# 409
# Loss: 0.18985917538404465
#  у, не мог:
# Как верил бы подруг
# Шернаюшке:
# Пес нам прежде до нем его любимы.
# М тонь утеса глубил, тебя речи.
# Но в нем стыслеей воловость.
# Я нежит соненец
# Обратится мне славы,
# И не остались с так тому н
# 410
# 411
# 412
# 413
# 414
# Loss: 0.19124623149633407
#  улышный град,
# Полнощный мне спокойных волокит
# (Которых бес для без собратин,
# Игра вольности молит сердца с поравно
# И скучаешь прорубить темна.
# И под пером Карамзина
# В родных преданьях прозвучало;
# Но н
# 415
# 416
# 417
# 418
# 419
# Loss: 0.19172164380550386
#  увеж, взор и легка,
# Весь брашет он бесплодных искушится,
# Дободечие муза честья;
# Я пот он в стране далекой горном
# И словам поле на верники? Что ж вечером,
# И сако моей прекрасные,
# И жало много он смотре
# 420
# 421
# 422
# 423
# 424
# Loss: 0.19104104936122895
#  улыбкой сид, я неч!
# Я бы сердца нековнет меня.
# Тослил он в страхе с поля брани,
# Где кровь черкесская текла;
# Отец и два родные брата
# За честь и вольность там легли,
# И под пятой у ночь тебя стоей.
# На кр
# 425
# 426
# 427
# 428
# 429
# Loss: 0.189155690073967
#  увесних
# Седость врагов был удал…
# Я всё надости сладостный сон обольной
# Принесную вой волнам
# Там чужда мне возможной горяет;
# Там требуя попробуйт и обманной,
# На грудь отданье креста
# По заминул он и пос
# 430
# 431
# 432
# 433
# 434
# Loss: 0.1891975086927414
#  увежду ларим
# По седа молны в ней читает,
# Не прошлого не любимой совети
# Ты коилности показались витом и давно,
# И верных русский высокой души мою
# Стоит с ними всюдиный глас.
# Оковы темные терпеть напрасн
# 435
# 436
# 437
# 438
# 439
# Loss: 0.19063586384057998
#  улыбкой брор,
# И все, что пред собой он в страхой
# Сердной бездной заточить
# Скрези молить по будет он.
# Дель он образы подо мной. С гасов, я рад отдам,
# И мотвые заплавет с вонутный логих,
# При душою дво в
# 440
# 441
# 442
# 443
# 444
# Loss: 0.1895513978600502
#  авканье далека,
# В услеза сердца выражает.
# Так бурны тучи огне,
# Он ни синею волной грузины!
# И так чувствои стоит светлый мир.
# Свершилось порок.
# Облаковах сабол ноги в стремена
# Не берегу скалы в темнать
# 445
# 446
# 447
# 448
# 449
# Loss: 0.1942205795645714
#  улыбкою простился,
# И трепет и ночь, удалет, вас безврегка,
# И учал поверь, живой стоны;
# Печь с какой перекрасный в неволе,
# На древо смерти внизу некомой,
# Про том скачет с породила,
# И звезды слушают мен
# 450
# 451
# 452
# 453
# 454
# Loss: 0.19377279072999953
#  улышный меня;
# В нем затилися меж ночной
# Кругом всё надость царица,
# Как дарик твоих чертах,
# И миртана и плотник, ты вздывасных
# Не слышен битвы шум отважный,
# И вот на другом забыла на горя и весте ночи,
# 455
# 456
# 457
# 458
# 459
# Loss: 0.19759924322366715
#  увеж, взор иль глупа,
# Доловалоный любовь.
# Пена вас больше нет, мы друга
# И выстрый зашанку —
# И светлой горний любовь,
# Перед тобою без нас весь он,
# Доманись, непраз и суждены,
# Тот столь гордокрушей поле
# 460
# 461
# 462
# 463
# 464
# Loss: 0.1587231634557247
#  увяжу молодая,
# В то нашенствии, все темных коварьсь на дорогу
# И выхольной рукой бесполезных дум,
# Презрел быть может, сердца нее сказать.
# Лошив соседельная крытые лодил
# Иним по ним мглым взоры
# Нав он м
# 465
# 466
# 467
# 468
# 469
# Loss: 0.13549854680895806
#  авкасла.
# Наемли был с тобой при дароко;
# Ты под светли давно уж и райские птицы.
# Иди себе дальше; о странник! тебя я не знаю!
# Я солнцем любима, цвету для него и блистаю;
# По небу я ветви раскинула здесь
# 470
# 471
# 472
# 473
# 474
# Loss: 0.12926176726818084
#  улыбкой брор,
# И все, что пред собой он в будет на дорогу
# И вышел не безвизнит была дуда,
# И выслый дев прочей волну плод я наровью,
# Не придут сестры с матерями,
# Покорный Как даром картенье,
# И вот дым с
# 475
# 476
# 477
# 478
# 479
# Loss: 0.1274425868690014
#  улыбкой сиять.
# На, ветночет и житель;
# Леставится негодая нежаньем
# Своего веретена?
# Выпьем, добрая подружка
# Бедной юности моей,
# Выпьем с горя; где же кружка?
# Сердцу будет веселей.
# Спой мне песню, как с
# 480
# 481
# 482
# 483
# 484
# Loss: 0.1250210575759411
#  улышли во небу,
# И в гружеских полны внизу не убежный,
# Он привет уре седит —
# Над немо меж тем любима, —
# Что с дитяю легков, нистви; неливою,
# Меня любить ты красоте сед,
# Донос и многая прогак,
# И волночн
# 485
# 486
# 487
# 488
# 489
# Loss: 0.12357406601309777
#  авкашле,
# Как страсти слово за променевести,
# Иль колыбели в не знаю терем изменина;
# Не пылите всевреми не мог:
# Я не сей восказа молодая,
# В поле он муки думая.
# И что за думают ли в сердце, ветер,
# Забру
# 490
# 491
# 492
# 493
# 494
# Loss: 0.12308068379759789
#  улыбкой золотой,
# На перепа, заряй, Бабрасась,
# И как нет же день
# Дать тридцать царских деревень
# С тем, чтобы тебя отнынул
# В молчанье правил грузный челн;
# А я — беспечной веры полн, —
# Пловцам я пел… Вдр
# 495
# 496
# 497
# 498
# 499
# Loss: 0.12076323628425598
#  у, не мог:
# Приждела она вас руке по временила
# И вот, ей наслажденья
# Твой шепот сладостный и тихий стон внимать,
# И тихо в страсти стану клясться всем;
# Со всеми буду я смеяться,
# А плакать не хочу ни с к
# 500
# 501
# 502
# 503
# 504
# Loss: 0.12057424575090409
#  улыбкой броривый,
# И нас любовь царицею травой
# Страстех собой, месяц осадит
# Он вете тебе с райских рук,
# И мынутился б — и одна.
# Но один бездрей вольной,
# Как привет он в море далекает
# Хоть без волнитья
# 505
# 506
# 507
# 508
# 509
# Loss: 0.11938965648412704
#  улышный в небесные,
# И клет славно своей
# К молчанью — так ужасна власть страстей!
# Тебя письмо страдальца не обидит…
# Я в жизни много — много испытал,
# Ошибся в дружбе — о! храни моих мучений
# Слова — прос
# 510
# 511
# 512
# 513
# 514
# Loss: 0.11871803909540177
#  улышли где булись грозно,
# Своего верстог стоит волно;
# В теперь одиноко с царевна цепокой
# И вас уж груди до средь серет.
# И к моей стороны толпы кинули,
# Не знаю, туманы над знала
# И сердье баладошь:
# Земл
# 515
# 516
# 517
# 518
# 519
# Loss: 0.11850425034761429
#  улыбкой свобода
# Он все поступая запутые,
# И просит ли в борый пененья
# Твой брат вас утеса мрачных деревеньный
# Не седленный и скале долина
# Навеко, гордили нежние,
# И звезда с боя
# Про даром привет учезами
# 520
# 521
# 522
# 523
# 524
# Loss: 0.11702407002449036
#  увеж, взор иль покорны;
# Будь на вор, создник как блести мое.
# И помню об ним грусть то мою.
# Как вы, мущен, весней в нены,
# В них следил он везде долина
# Наконец томит, видно,
# Как немла, платы над утрадил
# 525
# 526
# 527
# 528
# 529
# Loss: 0.11576282292604446
#  улышли поэта
# И делили старине, и всего
# В долины тебя страсть.
# Ты страшный на просторе».
# По всему и мирей при троны,
# И над поля он друга обман…
# Между собою своей отленья
# Темно я в сердце в груди глубок
# 530
# 531
# 532
# 533
# 534
# Loss: 0.11610018372535706
#  улышли вас будет,
# И не оспоривай глупца.
# С молодой с хотещали твое.
# Зачем в поле он меня…
# Последу с небесной суровость.
# Ты пил недавно, знаю я,
# Здоровье Дульской. Это новость;
# Кто эта Дульская?
# Равста
# 535
# 536
# 537
# 538
# 539
# Loss: 0.1161039985716343
#  улышный в небесные,
# И клет сердце девы,
# В то время на нее вершины
# И года моей не умор
# Дожду и тридцать сладостещие стоит
# Седную краса и блестят степей,
# И так я слишком долго видел
# В тебе надежду юных
# 540
# 541
# 542
# 543
# 544
# Loss: 0.11537494868040085
#  улышли где благодарила
# Что землей колыбуя;
# Тай мен он вот очей.
# Какою тихой берегам
# Гробляет на сомненья.
# Была та может в груди лубаву молчаньем
# Он славен под свободеной мины,
# И долго во мной блестит,
# 545
# 546
# 547
# 548
# 549
# Loss: 0.11563983276486396
#  улышняйте в вечным землем,
# Я вас любил бы я сердце;
# Он печальная девица
# Темно воды не изнашел.
# Отваждал он верь, наш моей.
# И розы и блистало
# И под пером Карамзина
# В родных преданьях прозвучало;
# Но нын
# 550
# 551
# 552
# 553
# 554
# Loss: 0.11559720143675804
#  улышный в небесный,
# Хоть стал и досей все же загототе,
# Что была благодатным и теснит,
# И так его ветер рукавами
# Его седло; узда с кистями;
# Под ним весь в мыле конь лихой
# Бесценной масти, золотой.
# Питом
# 555
# 556
# 557
# 558
# 559
# Loss: 0.11286925882101059
#  у, унежный Карад
# Быснесь с царевною судьбою,
# И звезда своем и видел не взор и вечерний простоты
# И ничьем и чужом как свой
# И тоск утро земля вад
# Была б горькомной суказала,
# И тот же может желанья
# Да, г
# 560
# 561
# 562
# 563
# 564
# Loss: 0.11297795280814171
#  уноком любовь,
# Стихий тревожный рой мятется —
# И здесь стою недвижим я.
# Стою!.. ужель тому ужасно
# Стремленье всех надземных сил,
# Кто в жизни чувствовал напрасно
# И жизнию обманут был?
# Вокруг кого, сей я
# 565
# 566
# 567
# 568
# 569
# Loss: 0.1130719818174839
#  улышняйте встреком,
# И странник к молвить, молодещенье
# Развали себе ночую ветрил
# Он стоит, другого друга долее,
# И в ней бежит сама такой
# Ив обо мне, свечку дальный папа.
# И прошлой на нее бустом
# Темной
# 570
# 571
# 572
# 573
# 574
# Loss: 0.11395192444324494
#  улышный венчанный и печальной,
# Глаза моей не зная куда.
# «Что, батька, так рано поднялся?
# Чего ты взыскался?»
# Поп ему в ответ: «Нужен мне работник:
# Повар, конюх и плотник.
# А где найти мне такого
# Служит
# 575
# 576
# 577
# 578
# 579
# Loss: 0.11200289338827134
#  улышный в сердце в тесно.
# И ветвях лет скрестник, теревель на меня:
# В награда облакать и камни!
# Тебе сердце в груди моей.
# Гарун с берегам горугом возруженьях полны;
# Там у него пирует,
# Молитви недавно,
# 580
# 581
# 582
# 583
# 584
# Loss: 0.11112551406025886
#  у, не всемцы,
# Леберен царь холодных род ужимый
# Одит, прошлых друг друга,
# Чтобы друг друга позабыть.
# Отныне стану наслаждаться
# И в страсти стану клясться всем;
# Со всеми буду я смеяться,
# А плакать не хо
# 585
# 586
# 587
# 588
# 589
# Loss: 0.11182219117879867
#  улышлю с постит;
# Лишь тиха прему и поле.
# Его об огонь томленный пененный судьбою,
# Он разговор во небу, ни сердце избумранный,
# И вот в око не могу статил
# Винтасть моей, не песь на просторе».
# Воротился
# 590
# 591
# 592
# 593
# 594
# Loss: 0.11271723285317421
#  улышли в ответ:
# «Ты помнишь, молчанье прором;
# Я не дал к одно быть может,
# Ревкрую певица! —
# И вот нашла бы все молиться работник.
# Но в нем с утой в немом затвене
# Моя темная прими гранит,
# Что скачать п
# 595
# 596
# 597
# 598
# 599
# Loss: 0.1115115562081337
#  улышный в сердце в тесно.
# Но терлить невод ней для чего,
# И на слеза, ваши рочи,
# Свозбудительный у нем.
# Вот потом чевских полны;
# Так бучные спробтовой.
# Как волсу с небезлим остала
# И ценою ветвей, и сво
# 600
# 601
# 602
# 603
# 604
# Loss: 0.11320083647966385
#  улышли вас ногу…
# Твой зер слава меня всяконцы взоры,
# С нашим разговором возданьям.
# Пославенные страдал,
# И волны в небес угесь с бесполе.
# Забыл я — забыть не даст их любкима,
# И горделись стеревней,
# И т
# 605
# 606
# 607
# 608
# 609
# Loss: 0.11214249417185783
#  юнось прибренья
# Теперь напин я и поля,
# Одно восторга поле.
# Он страстёт стало привет ужий.
# Но чудный правошный…
# Коко полей, нем солов,
# Когда он беден был и мал,
# Когда молва его не знала;
# Зачем с неженс
# 610
# 611
# 612
# 613
# 614
# Loss: 0.11049660995602607
#  у, еж новых,
# И дерял под новой желтеют,
# И та пыли красная обманет,
# И так гордценье сердца выражний души;
# Все чувства в ней кипели вдруг;
# Душа рвала свои оковы,
# Огонь по жилам пробегал,
# И этот голос чу
# 615
# 616
# 617
# 618
# 619
# Loss: 0.11059725984930992
#  улышли вас больной.
# Там лища светлый день,
# Встречал на крылься в мыслег,
# Торжественно приветливо застрет;
# И в раскали бы вольной отважных,
# Невеля там леса,
# От чувствой красоты полны,
# Как бы под ними т
# 620
# 621
# 622
# 623
# 624
# Loss: 0.1098670619726181
#  уноком любовь
# Прель верс — теперь в обрагов летят;
# Лишь в бору поникши ели
# Зелень мрачную хранят.
# Под нависшею скалою
# Уж не любит, меж цветов,
# Пахарь отдыхать порою
# От с одновая девица
# Мвергет на крыл
# 625
# 626
# 627
# 628
# 629
# Loss: 0.10859986335039139
#  улышли вас?
# В душе терзаем ум тебя я не радонесть,
# И недаваньями годы!
# Любить… Но кого же?.. На время — не стоит труда,
# А вечно любить невозможно.
# В себя ли заглянешь? — там прошлого нет и следа:
# И ра
# 630
# 631
# 632
# 633
# 634
# Loss: 0.10822014957666397
#  улышный в соберея
# Любви моей не зорной,
# Но ты мне пропал и поле,
# Ревел я праведал — и вечерний глачен.
# Но клодо ль ихолет;
# Души в окно поверь, —
# И счастье она со мною?
# И скоро ль, на радость соседей-в
# 635
# 636
# 637
# 638
# 639
# Loss: 0.11082835674285889
#  авкам волны,
# Он забыто. Наш герой
# Живет в Коломне; где-то служит,
# Дичится знатных и не тужит
# Ни о почиющей родне,
# Ни о забытой старине.
# Итак, домой пришед, Евгений
# Стряхнул шинель, разделся, лег.
# Но д
# 640
# 641
# 642
# 643
# 644
# Loss: 0.10961445599794388
#  улышлю с постит;
# Лежал не золные тенчанный судьбою,
# Он дороги томительный не узнали.
# Богатыри — но ветер!..
# Но дели встречу и летам,
# И так лежал над сердце в поля, —
# Меня так пошла в жилий темной
# Он м
# 645
# 646
# 647
# 648
# 649
# Loss: 0.10930579334497452
#  авкам волны,
# Он закону сказать не мог;
# Так ветренной тревогу,
# Не в след, шелкою пробужденья
# Твоей печали добычать?
# Теперь огонь вдохстрона
# И надоврать на крыльцо;
# В гнать не дал я стайнутилься всё в д
# 650
# 651
# 652
# 653
# 654
# Loss: 0.10988972440361977
#  улышный в сердце в техой
# Услым нас обить. Россог да завы,
# В то время на нее вернуть вольной,
# С тон в море закинул невод, —
# Пришел невод с одною листов
# На конец по страшные ветертыельная тресит,
# И тот
# 655
# 656
# 657
# 658
# 659
# Loss: 0.10977341011166572
#  улышный в сердце в тесно.
# Но терем и постыдно родного ветвей,
# То вденею, в отныне в море далаю;
# По грозной печали благодарил,
# Когда поле с позранится за славился
# И наконец отчахнику!
# Я был с ближе дыл
# 660
# 661
# 662
# 663
# 664
# Loss: 0.10991846814751625
#  южисти волив,
# И будут цепокой взор молоду.
# Простыне морем волка
# Я старый добманье,
# И года царица: ылающий птицы
# Ма ном поля с ней, — и назначенье.
# Своей как больше нет волнений,
# Прости, мой друг», — и
# 665
# 666
# 667
# 668
# 669
# Loss: 0.09709358789026737
#  улышный в ненец
# И скроется за может,
# И как будто слышит был толпою люблю,
# Не для него воскресли вновь
# И божество, и вдохновенье,
# И жизнь, и слезы, и любовь.
# Плоняет сердца молодая.
# И вот она, одной ру
# 670
# 671
# 672
# 673
# 674
# Loss: 0.09013587564229965
#  улышный в неволе,
# Любил бы снегу с топастый
# Души через море,
# Была б залобою пролята.
# В глуши, в думай, полны; б облак —
# И они мне воззвал дальным протеты,
# Бариское слабов без цели,
# И ко дни с скалы вл
# 675
# 676
# 677
# 678
# 679
# Loss: 0.08681301191449166
#  улышный в соберея
# Любви моей не знаю!
# Я солнцем любима, цвету для него и блистаю;
# По небу я ветви раскинула здесь на просторе».
# Воротился старик ко старухе,
# Рассказал ей великое чудо.
# «Я сегодня пойма
# 680
# 681
# 682
# 683
# 684
# Loss: 0.08624245285987854
#  улышный в сердце в тесно.
# Но терем и постыдно равнодушны,
# В начале поприща мы вянем без борьбы;
# Перед опасностью позорно малодушны
# И перед властию — презренные рабы.
# Так тощий плод, до времени созрелы
# 685
# 686
# 687
# 688
# 689
# Loss: 0.08551679246127605
#  улышный в неволе,
# На дремлет суга полны,
# Свободы при тручей мне другом,
# Проверзусный первеникой любовь,
# Печали б отдаться и всего
# В дорога молитву —
# И к ревой в поравный листочь
# Кроволь под небесной в
# 690
# 691
# 692
# 693
# 694
# Loss: 0.08448822692036628
#  улышный в неволе,
# Она с ними грусть то мой
# Он стоял предалися меги моей,
# Вечернем прибавил старый Кочубей.
# И то сказать: в Полтаве нет
# Красавицы, Марии равной.
# Она свежа, как вешний цвет,
# Взлелеянный
# 695
# 696
# 697
# 698
# 699
# Loss: 0.08371563911437989
#  улышный венцом
# Огни сея могучь, ветерла.
# Что к изменит томуты ты,
# Да моей блеск у и темно,
# И милого северна от она
# На кровать нас улыбку —
# И оба врагов седум темнокого
# От вас образы покрыты дни мои?
# У
# 700
# 701
# 702
# 703
# 704
# Loss: 0.08410420894622803
#  улышный в сердце в тесно.
# И под скалою живят;
# Страшите все мне тем накаснет
# Уж ты стран страстяте следа
# Приветливо крик молодой,
# С тоской рузьих их мою откачей.
# Ложать старотиль синее по трожу своим
# И
# 705
# 706
# 707
# 708
# 709
# Loss: 0.08347916573286057
#  улышный велее,
# Всех небу ли нимый венчанный суд;
# Он соррошивал на кровь и потела.
# Что киха него битво сомненье
# Темнила без славу
# Под светлые дочерье
# Подкогда носкаяся милый куп лай.
# С мороси семью кра
# 710
# 711
# 712
# 713
# 714
# Loss: 0.08281080439686775
#  улышный в сердце в тесно.
# И снить ужаса, вста перевозкими изнали,
# Волненек она благородный,
# Смотрит в поле непостал;
# Но не мог ли его в окном,
# Как безумный в ненец, и далека светлой увереть
# Сторожеща
# 715
# 716
# 717
# 718
# 719
# Loss: 0.08249580420553684
#  авкам волны их море.
# Почит он в мырей подписал:
# Под дороги долго голос надераяшит.
# 2
# На пилающие затило,
# И несчастья в моей,
# Страние пробиравной засенник.
# И берегва сладостным с бравний цвето,
# Меж лис
# 720
# 721
# 722
# 723
# 724
# Loss: 0.0826163811981678
#  улышный в сердце в тесно.
# Но торпели добрые слова,
# Попалеет да залаяся
# Вкруг хочу всеми лания
# Не смеял больностью залая,
# Про темная рассеще; за мило,
# И перед ним прежде же всегда ревох
# Воспоминаньем и
# 725
# 726
# 727
# 728
# 729
# Loss: 0.08205929443240166
#  улышлю с постит;
# Лишь тиха преговор его кудрей.
# Смежит по ней собой, ни тучень от с разрушенье правом
# Рожив их бесчиву грозный пламень,
# Все порок вечерком.
# «Кабы я была царица, —
# Говорит одна девица,
# 730
# 731
# 732
# 733
# 734
# Loss: 0.08152723297476769
#  улышный венчанный ночь?»
# Посларянный на просторе».
# Посладя далекой лого
# На днями разгоровалый,
# И долго видел прийную девица
# В сердце отдала.
# В паденья не дал кводь поле моля
# Мне ты дремлет святые Тере
# 735
# 736
# 737
# 738
# 739
# Loss: 0.08172045536339283
#  улышный Иодел
# В ту ларевний кровь и простой дочерь,
# Но пруд устри наслажденья
# Твой шепот сладостный и тихий стон внимать,
# И тихо в скромной тьме для неги пробужденья
# Близ милой засыпать?
# Холовил он ве
# 740
# 741
# 742
# 743
# 744
# Loss: 0.08223731338977813
#  улыбком спольной
# С тубребе дальный недруг степей.
# Как тот он и померевною любовь,
# Перед собою слов больное мной.
# Всё правда померял он, чистым,
# В глазах он моим я ни свете волночной
# И с над бестою сво
# 745
# 746
# 747
# 748
# 749
# Loss: 0.08084974467754363
#  улышный Иостон:
# Лавственная холодной младыми?
# . в тех дось мне счастия не ищет
# И не от счастия бежит!
# Под ним струя светлей лазури,
# Над ним луч солнца золотой…
# А он, мятежный, просит бури,
# Как будто в
# 750
# 751
# 752
# 753
# 754
# Loss: 0.08156706184148789
#  улышный в неволе,
# Она придет; но вот уж ночь,
# И скоро месяц уж покинет
# Небес далеких облака, —
# Земфиры нет как нет; и стынет
# Убогий ужин старика.
# Но вот она; за нею слово молодая.
# Их крают вечной тепе
# 755
# 756
# 757
# 758
# 759
# Loss: 0.08134917989373207
#  улышней, скупит и всем!
# Сколучима своей от голонесный
# Волненье бесплодной грозный кум на свете
# Строна старый мои темно,
# И милой уры мне, и слезадно;
# В полеща славой покрушленья
# Твой шепот сладостный и
# 760
# 761
# 762
# 763
# 764
# Loss: 0.08154627472162247
#  улышный в неволе,
# Она суждена там ли тебе на свете
# Технуть не досчится мне славы
# Над ним склонялись головой,
# Следя мелькающие волны;
# И башни замков на скалах
# Смотрели грозно сквозь туманы —
# У врат Кав
# 765
# 766
# 767
# 768
# 769
# Loss: 0.08108913317322732
#  улышней-кати споре,
# Он чем я не так лет и три года.
# Старик ловил неводом рыбу,
# Старуха пряла свою пряжу.
# Раз он в море закинул невод, —
# Пришел невод с одною тиной.
# Он в другой раз закинул невод, —
# При
# 770
# 771
# 772
# 773
# 774
# Loss: 0.08028274282813072
#  улышный в сердце в небесной
# Всегда ей белее, чем да залабеть
# И к нем в окном уж востом
# Дорогой в славен буду я ничего
# Степелый миня взглядыт,
# Стезей постою взором озадаленный,
# Лети, ко друг стал осенн
# 775
# 776
# 777
# 778
# 779
# Loss: 0.08008664198219777
#  улышный в сердце в небесной
# В светлой горни вдали врад;
# Он заметил небегами.
# А где же далекает молодица
# В деревне скучно: грязь, ненастье,
# Глядел под полуть у под небо ли, —
# Яли багник пробежал?
# От их
# 780
# 781
# 782
# 783
# 784
# Loss: 0.07978983215987683
#  улышный венчанный туман;
# Но в нем хталусь лет и три года.
# Старик ловил неводом рыбу,
# Старуха пряла свою пряжу.
# Раз он в море закинул невод, —
# Пришел невод с одною любовий:
# «Не прах один перед и поколь
# 785
# 786
# 787
# 788
# 789
# Loss: 0.07974781766533852
#  уноко ласкою,
# И песни брашет по стременились в тридца,
# Друга дорог, то не могу
# Обиду каты друг, ему.
# Отныне красоте над страстих,
# Тока, пашет он славу морской — и грудь;
# И вновь призник он и замести с
# 790
# 791
# 792
# 793
# 794
# Loss: 0.07959275916218758
#  улышней-кати штой проре даляет.
# Лорве лишь видит в очах, и Кав обой,
# Он вас божественный толпой,
# Таинственной синем волненья
# Смирив я камил и потеренный ручьи
# И страдальний в немом, ты мне от сестры,
#
# 795
# 796
# 797
# 798
# 799
# Loss: 0.07962380245327949
#  улышный в неволе,
# Она сужденья для него и закали
# На челу ск с борьбы е на врада.
# Усречь погруженая порания.
# Была б рывестию листока,
# Ведет богатый караван.
# Ремнем затянут ловкий стан;
# Оправа сабли и к
# 800
# 801
# 802
# 803
# 804
# Loss: 0.07956331066787242
#  улышней-ках домой
# Лишь глаза он меж тем еще ветви
# Приветливо стигнит —
# И предавшись, томитавшим;
# Я б стран страстей поздним их рожде,
# И руке собое осезда
# Дорогой любя не упадет:
# Донось пожатстрой прав
# 805
# 806
# 807
# 808
# 809
# Loss: 0.07889771431684495
#  улышный Иод,
# Отмиливой росой не знали;
# Тех прошлоду самолюбивая толпа,
# Которая от мудрости глупа,
# Ужели дев коварная любовь
# Прельстят меня перед кончиной вновь?
# Ужели захочу я жить опять,
# Чтобы душой
# 810
# 811
# 812
# 813
# 814
# Loss: 0.07886998362839222
#  улышный Искатил
# Илаговой один я на просторе.
# Прошло сто лет, и юный град,
# Полнощных стран краса и диво,
# Из тьмы лесов, из топи блат
# Вознесся пышно, горделиво;
# Где прежде финский рыболов,
# Печальный пас
# 815
# 816
# 817
# 818
# 819
# Loss: 0.0788986112177372
#  улышный Искатил;
# По томи руком холодом на свой гробница
# И над скучался в сердце губимый.
# Его на дерево он и друзей
# Надежды лучшие и голос благородный
# Неверием осмеянных страстей.
# Едва касались мы до в
# 820
# 821
# 822
# 823
# 824
# Loss: 0.07791020557284355
#  улышный в неволе,
# Она сужда меня ошей с поля:
# Невила чисама, присила.
# В душе теребе послушною сердце.
# Царь оправита нишь, в темная от она,
# И тихо, верно свет, не измени;
# Он сколько подпил его я
# Старин
# 825
# 826
# 827
# 828
# 829
# Loss: 0.07802304863929749
#  улышлю с постит;
# Глаза — и безмолный огни;
# Вот музы нежные бует.
# Царь Салтан волной блеской —
# И к думое полный страстей,
# Груг скалы тах на просторе».
# По мне прошлого ничуть ли его владыки
# На злая молю
# 830
# 831
# 832
# 833
# 834
# Loss: 0.07830157347023486
#  улышный Искатил;
# Когда б иственья не оставить
# Хтем я печальная нижес,
# И раз учас ложество движенья
# Так стройны, полны выраженья,
# Так полны милой простоты,
# Что если б Демон, пролетая,
# В то время на нее
# 835
# 836
# 837
# 838
# 839
# Loss: 0.07808514304459095
#  улышный в сердце в тесно.
# Под ним веселый думая на просторе».
# Воротился старик ко старухе,
# Рассказал ей великое чудо.
# «Я сегодня поймал было рыбку,
# Золотую рыбку, не простую;
# По-нашему говорила рыбка,
# 840
# 841
# 842
# 843
# 844
# Loss: 0.07776518993079662
#  улышный Иод —
# Ее не признали наглой воли
# Того, под кем дрожали вы?
# За то ль, что в бездну повалили
# Мы тяготеющий над царствами кумир
# И нашей кровью искупили
# Европы вольность, честь и мир?..
# Вы грозны
# 845
# 846
# 847
# 848
# 849
# Loss: 0.07840146146714687
#  улышней-как никого.
# Но утах его ты в тесно.
# Но торчи раз умодных он дальный
# И всё, чем я страдал, и всё, что сердцу мило,
# Желаний и надежд томительный обман…
# Шуми, шуми послушное ветрило,
# Волнуйся под
# 850
# 851
# 852
# 853
# 854
# Loss: 0.07895810924470424
#  улышный в сердце в тесно.
# Под ним веселый думать
# И показлуска и дружбе…
# Не будет меня на другом,
# Селим пришельца не узнал;
# На ложе, мучимый недугом, —
# Один, — он молча умирал…
# «Велик аллах! от злой от
# 855
# 856
# 857
# 858
# 859
# Loss: 0.0775049827992916
#  улышный в ненец
# И скровь породие дослал
# Ибит они забав на свете
# Ты царевны молодой?
# Я жених ей».— «Свет ты мой, —
# Красно солнце отвечало, —
# Я царевны не видало.
# Знать, ее в живых уж нет.
# Разве месяц,
# 860
# 861
# 862
# 863
# 864
# Loss: 0.07794635370373726
#  улышней-качить
# Хоть еями отвечал он вдруг увидят;
# Когда служит холодным внимали;
# Да свичить ненеб тебя; не раз за нога,
# И учизни отверженный улыбе с читиится,
# Домовремится он моррой их вечной мир,
# Гар
# 865
# 866
# 867
# 868
# 869
# Loss: 0.07714713245630264
#  улышный Искатил
# Илаговой укоров и тоскою здесь слывин
# Дал он отца не зная куда.
# «Омрада, где сине-ночь, не дал южств, —
# Гарит он и кровавне одна веселых
# В тот послушно я в тишине,
# Произнеси его тоскуя
# 870
# 871
# 872
# 873
# 874
# Loss: 0.07730556048452854
#  улышлю с постой,
# На пир забыла в мир розий,
# Вспомина ты желает гордели,
# Волненье доленые поля,
# Кричет призгал шумит;
# Всему вольность моя пола
# Не на сердце дось?
# Ведву о на друга другимый;
# По зависти х
# 875
# 876
# 877
# 878
# 879
# Loss: 0.07746730551123619
#  улышняет за дару,
# С ней госодивать сердца другого
# Одна челный жизни след
# И над головой прелед ни одна давно,
# На нем по стог уселу поэта
# Велица вечерной засенник.
# И счастье она со сторонам,
# Усели, забы
# 880
# 881
# 882
# 883
# 884
# Loss: 0.07785991460084915
#  улышный в сердце в тесно.
# Под ним веси народы из волом;
# Понись променят покрыту из оклапа,
# По брожей мертвенней и песни;
# Порет царевной груди и желтые лицей,
# И слишком волтавах и грустной
# Проверение м
# 885
# 886
# 887
# 888
# 889
# Loss: 0.07697405725717545
#  улышный Искатил
# Илаговой укоров и тоскою здесь словы не знаю вас
# И над землей солнца,
# Показ уналие родины,
# На кровсть их лутько угра остала;
# Не празднике прекрасные набытио,
# И тиерки трях, все смерть
# 890
# 891
# 892
# 893
# 894
# Loss: 0.07643951341509819
#  улышный Иогни
# На звук того лет;
# То вдруг лов как света от показалой
# Вдруг солнь мысленной тени.
# И век испокого старину свою струя;
# Шесних испугал ущеньет.
# Все кровь течет по ней собою,
# Ребленека любов
# 895
# 896
# 897
# 898
# 899
# Loss: 0.07617504246532918
#  улышный в сердце в небесной
# Всегда ее моны,
# Как в стремя на свете волны.
# Опасен, узок путь прибрежный!
# Утесы с левой стороны,
# Направо глубь реки мятежной.
# Уж поздно. На вершине снежной
# Румянец гаснет;
# 900
# 901
# 902
# 903
# 904
# Loss: 0.07701272428035737
#  улышный в неволе,
# Любимой я солнцем ли, и время из вас?
# В дорогда на мы бестучена;
# Ино в кров, или тебе царь,
# Стороны толпой молодой
# И корме с тобой золотой,
# Не куть жистали боевыя ни речь.
# В сердце с
# 905
# 906
# 907
# 908
# 909
# Loss: 0.07683067008852959
#  улышный Иоб
# И милость всё права стеклах
# Вся белее братильная провестец
# Сердите счастье обольность,
# Где крылись его вздыхой.
# Пришлец и там грепния как синица
# Свою рассказ он и чужды, слад зарить.
# Но в
# 910
# 911
# 912
# 913
# 914
# Loss: 0.07669927582144737
#  улышней-как изнеравное мгновенье:
# Передо мной явилась ты,
# Как мимолетное виденье,
# Как гений чистой красоты.
# И сердце бьется в упоенье,
# И для него воскресли вновь
# И божество, и вдохновенье,
# И жизнь, и
# 915
# 916
# 917
# 918
# 919
# Loss: 0.0768960676342249
#  улышняй в ответ:
# «Ты, царица, спору нет,
# Ты на свете всех милее,
# Всех румяней и белее?»
# И ей зеркальце в ответ:
# «Ты прекрасна, спору нет;
# Но живет без всякой славы,
# Средь зеленыя дубравы,
# У семи богат
# 920
# 921
# 922
# 923
# 924
# Loss: 0.0772124482691288
#  улышней-качить
# Гоедимой коварная любовь
# Прельстят меня перед кончиной вновь?
# Ужели захочу я жить опять,
# Чтобы душой по-прежнему страдать
# И столько же любить? Всесильный бог,
# Ты знал: я долее терпеть н
# 925
# 926
# 927
# 928
# 929
# Loss: 0.07710893884301186
#  улышный Искатил
# Илаги солнце он беспучи:
# Боров и царицы,
# квярешие с лебя не знаю как нет,
# Ты на моей чертах и трудухей
# Он давит и свободен я:
# За то, и бак себе имил на дравай
# Не ним склоняться ниже до
# 930
# 931
# 932
# 933
# 934
# Loss: 0.07189820803701878
#  улышный в сердце в тесно.
# Под ним веси народройсь, —
# И под печу царевич в чуждые,
# Да мое, над стране дочей,
# Как будто бы знают я здемной,
# Он сточут меня оставленный позор,
# Ночь губить несчастья во род
# 935
# 936
# 937
# 938
# 939
# Loss: 0.06851385772228241
#  авцан царевнованьем,
# Полетил бы не оставить
# Спит свой средь боясь,
# Всегда струсил пришлец одиноко
# На кровле ли я на как и ж? ветвя наслажденья
# Твой шепот сладостный и тихий стон внимать,
# И тихо в скро
# 940
# 941
# 942
# 943
# 944
# Loss: 0.06803746461868286
#  улышный Иогни
# На дерзов породы лукену я ноча
# Мильном потяжений звук твоих следов
# Втай ноим тревожный рон обман,
# Иселю говорят, вы нелюдим;
# В глуши, в деревне всё вам скучно,
# А мы… ничем мы не блестим,
# 945
# 946
# 947
# 948
# 949
# Loss: 0.06714499585330486
#  улышный Иогни
# Он в сердце отавитлом бередера,
# Изгнанью суровов отраду
# В дененье братил он?
# В отдали я в сердце девица
# За водой бичи;
# Под долгой пролеговолнесть.
# Гружи у наслажденья не виду —
# Примасил
# 950
# 951
# 952
# 953
# 954
# Loss: 0.06722128421068191
#  улышный Иогни
# Рассени, что так и слез одасай
# Мне тайно поле на друга,
# И повсемченье с море.
# В труд хуто взмон снег лаская нет.
# День и все на мы вечной верными трекомы.
# Ужит по двору разбитили
# Зи полны
# 955
# 956
# 957
# 958
# 959
# Loss: 0.06770794734358787
#  улышный в сердце в тесно.
# Под ним веселый думать
# Он солобил он в глазах ее — и красавице;
# Любви с небесной гривой:
# В тать как туман вот поляных рек,
# На камаля семью с тоскаю;
# Кто ли с ворошь мне там о
# 960
# 961
# 962
# 963
# 964
# Loss: 0.06707939326763153
#  улышный в сердце в тесно.
# Под ним веселый думать в перед тела.
# Пенья через пороги крата;
# Он все на сердце деть.
# Давно ль богатыря на кровью
# В том размелостью золотая,
# Мой на свете воспремя и все меж
# И
# 965
# 966
# 967
# 968
# 969
# Loss: 0.06633517123758793
#  улышный Иогни в жизни мне так долнен;
# Не видать вас густи мучить свет
# Даль немой с тому
# Я несчастьястый лем».
# Есть тревой с поля брани роковые,
# И преступленье с меня!
# И вы, курь осенник печаль,
# Но в н
# 970
# 971
# 972
# 973
# 974
# Loss: 0.06711891382932662
#  улышный Иоб
# И милость всё права, заботливо,
# Восплену жений стройна, безумно.
# И под страдал, и всё там ничтожно…
# Что страсти? — ведь рано иль поздно их сладкий недуг
# Исчезнет при слове рассудка;
# И жизн
# 975
# 976
# 977
# 978
# 979
# Loss: 0.06603297375142575
#  улышный в сердце в тесно.
# Под ним веселый думать
# Он солами нас тихонько Кором
# Досланится он, — и ее обманут
# Овподдум летель с море десь на дорогу.
# В последних числах сентября
# (Презренной прозой говоря
# 980
# 981
# 982
# 983
# 984
# Loss: 0.0663092514872551
#  уноко имена
# По верь послушно, злоба,
# И незнак и челистают холодной
# И самог дальней и пустой,
# И стесли мою стоит роковою
# Души слупами надомы,
# Они крытыл своей укасадил
# Мой ум на поздникокого ветвей,
# То
# 985
# 986
# 987
# 988
# 989
# Loss: 0.06647721968591214
#  улышный в неволе,
# Любили друг друга постой в тобой.
# В тем я вас бубей с мака, —
# Приятчальных сил бог еще нет,
# Безя душою небесные,
# И звезды яски без свободу,
# И в небесах торжественно и чудно!
# Спит зем
# 990
# 991
# 992
# 993
# 994
# Loss: 0.0665435566008091
#  улышный в сердце в тесно.
# Под ним веселый дел, верно свет,
# Ты волны степил он властью одна.
# И слишком дороговая люков
# Велевала и признанья,
# Тот холодной мукие милины
# И трещал бы отдомная мне.
# За невес
# 995
# 996
# 997
# 998
# 999
# Loss: 0.06624219968914985
#  улышный Иод, —
# И счастье она там не знаю из
# Нетенка, порачьем любима, цветущую молиться не узнил
# И потом в пустыне я ни благодал,
# Ни темношущий перед
# Стоял над скачет.
# Кони молвить невастию — и о нем
# 1000
# 1001
# 1002
# 1003
# 1004
# Loss: 0.06521834492683411
#  улышней-кихала
# С бойся в горах горают он;
# Встречали все внимальнами главой,
# И не робился с там прости!
# Тем лес и за него дочь ни по утренный судьбою,
# Он раздум любовь смерлец винов,
# Таком тебе своей
# К
# 1005
# 1006
# 1007
# 1008
# 1009
# Loss: 0.06592450812458991
#  улышный Иод —
# Ее не правдых ножод, инав,
# Ты ночь, не дал южств, истог оботный,
# И вот прекрасная море,
# Поров однены, что он ничем спасенье.
# Приди ко мне, прелестный ангел мой,
# И мирное прими благослове
# 1010
# 1011
# 1012
# 1013
# 1014
# Loss: 0.06593599297106266
#  улышный Искатил
# Илаги солнце он пришел не знаю!
# Я солнцем любовь я но нас,
# И всев верились из голницы
# Гилистых ли наш рано наслаждать;
# Что вопром со нее речи,
# В тот грозить обрушенных зеленых,
# И что в
# 1015
# 1016
# 1017
# 1018
# 1019
# Loss: 0.06505820654332638
#  улышный в сердце в тесно.
# Под ним весь в мыле конь полны,
# И страна дев мой брат!
# Обеты теплые с мольбами
# Забыл ли? Год тому назад
# Мы были нежными друзьями…
# Ты помнишь, помнишь, верно, бой,
# Когда рубил
# 1020
# 1021
# 1022
# 1023
# 1024
# Loss: 0.06497080326080322
#  улышный в неволе,
# Любили друг друга постой в тобой;
# Не видать ничьих следов
# Вкруг того пустого места,
# В том гробу твоя невеста.
# Несчастью тепла в сердца людей».
# И так лет и внистынной дал со временить
# 1025
# 1026
# 1027
# 1028
# 1029
# Loss: 0.06575313210487366
#  улышный в неволе,
# Любили друг загожу царь-отеи за ней,
# На кровавно ль и постит;
# Там народной грусть и взором,
# Афедрон ты жирный свой
# Подтираешь коленкором;
# Я же грешную дыру
# Не балую детской модой
# И Х
# 1030
# 1031
# 1032
# 1033
# 1034
# Loss: 0.06584155768156051
#  улышней-ких оз.
# С огравы — взой нас вас больше не раз убести
# Полны у сердца нековнет,
# Спотам. Он украд, очей белают —
# Не встретит и с небесние грусть,
# И то в дереволами своей не узнали
# Забыла с тобой
# 1035
# 1036
# 1037
# 1038
# 1039
# Loss: 0.06511598877608776
#  улышный Нес;
# Лишь содним сном с тому нет,
# Дахо всё, на свете лишь иль отказалин,
# Испа льются не знаю радость
# В сметил с утра всевней?
# Он нашала свою склонесь едима;
# С тех пор как мир лишился она
# С хол
# 1040
# 1041
# 1042
# 1043
# 1044
# Loss: 0.06489203378558159
#  унокого замятей,
# На време на месяц улыбку.
# Уж и богатырь и смерть под небору в тихой,
# И все, что пред собой он видел,
# Он презирал иль ненавидел.
# В серным казакомой улицы,
# Тарос никожб и киданья!
# И был
# 1045
# 1046
# 1047
# 1048
# 1049
# Loss: 0.06468771554529668
#  улышный в сердце в тесно.
# Под ним веселый думать опрени;
# Он позабыла в горько подругой богатырей
# Там заряд уж гропета;
# Он воштысть вас тихостего
# Мой пределати вражды ни желать
# Моржестве наша волен отв
# 1050
# 1051
# 1052
# 1053
# 1054
# Loss: 0.06526942558586597
#  улышный в сердце в небесной
# Его вам теперь на просторе».
# Воротился старик ко старухе,
# Рассказал ей великое чудо.
# «Я сегодня поймал было рыбку,
# Золотую рыбку, не простую;
# По-нашему говорила рыбка,
# Домо
# 1055
# 1056
# 1057
# 1058
# 1059
# Loss: 0.06444056712090969
#  , нашлющих именем
# То вершие тений бури,
# Да вряд ли есть родство души.
# Страницы прошлого читая,
# Их по порядку разбирая
# Теперь остынувшим умом,
# Разуверяюсь я во всем.
# Смешно же сердцем лицемерить
# Перед
# 1060
# 1061
# 1062
# 1063
# 1064
# Loss: 0.06519465312361718
#  улышный в сердце в тесно.
# Под ним веселый думать
# Он счастливый мои громкие злобно,
# Но ни свеготошно все долины
# Темний над пустыне,
# Послетел за стал блеснится за колненья
# Мне долго вот грозой, ты горда
# 1065
# 1066
# 1067
# 1068
# 1069
# Loss: 0.06409828126430511
#  улышный Искатил;
# Когда с тобою, сквозь туманы и ДесерВельний вол,
# И бранный звон он слава — и лежен;
# Но в их говори моих мучений,
# Простал поле наповрадился они моя.
# Люблю я солнце огони жена;
# Он слыши
# 1070
# 1071
# 1072
# 1073
# 1074
# Loss: 0.06395945467054844
#  улышный в сердце в тесно.
# Под ним веселый темной в ответ:
# «Ты, царица, потвирая,
# Впоравы не сонишь то не простительная тучи;
# Невидель низну сладостной рукой
# Струями ставнями отраванный,
# Пустанек учихо
# 1075
# 1076
# 1077
# 1078
# 1079
# Loss: 0.06457867607474327
#  улышный Искатил
# Илаги солнце он беспучны? —
# Под ним струя светлей лазури,
# Над ним луч солнца золотой…
# А он, мятежный, просит бури,
# Как будто в бурях есть покой!
# Ка молчанье голубого усердья врагом
# В т
# 1080
# 1081
# 1082
# 1083
# 1084
# Loss: 0.06486557938158512
#  улышный в сердце в тесно.
# Под ним веселый думать опреньной,
# За серед лена всех недуг
# Оботнец безунительный недуг
# Развил тогда могучий дух
# Его отцов. Без жалоб он
# Томился, даже слабый стон
# Из детских г
# 1085
# 1086
# 1087
# 1088
# 1089
# Loss: 0.06460336118936538
#  улышный Иоб
# И милость всё параСтеч возмутило
# Рассеял своих с меня, молю,
# И года мне об он спаленья,
# Как гласть гордого моря чинулистый,
# Есть в мире сердце мелоконный!
# Но мило пред жалюду, —
# То с ним,
# 1090
# 1091
# 1092
# 1093
# 1094
# Loss: 0.06464431889355182
#  улышный Иоб
# И милость всё права, все черетеет,
# И сак странна моей друг, ему
# Дара над сказал он рыбку,
# Наге вернощенье волны,
# И звезда с боя волны и мирского
# Из пламя и света
# Рождённое слово;
# Но в храм
# 1095
# 1096
# 1097
# 1098
# 1099
# Loss: 0.06424376733601093
#  улышный в сердце в тесно.
# Под ним веселый думать
# Моржеский рассказ осталась его
# Вхожу всё как весь путь при труда,
# Свободее не водой,
# С крагов позадье дорогу
# Обрасные, все поле он
# С стоим кровь опоре
# 1100
# 1101
# 1102
# 1103
# 1104
# Loss: 0.06403224304318428
#  уноко имена
# Темние верная паль; во недет.
# Разврашь з надежде, любил…
# Теперь тавно пошелка
# Моий тепло с тобою,
# Не приданое день,
# Осено мне такого Гирея,
# Он блинитво возвестал есты.
# Ужель следал он росо
# 1105
# 1106
# 1107
# 1108
# 1109
# Loss: 0.06237023331224918
#  улышный Искатил;
# Когда б их месяц здесь не он,
# Дого бы горят,
# И пене сон ободенный родит
# И песни грозная вас!
# Зарек, утомить обрушенных коньствимой,
# Что мгновенье братил он рыбка!
# Това унылом весело
# Е
# 1110
# 1111
# 1112
# 1113
# 1114
# Loss: 0.061247513666749
#  уноко лады
# И годы листое вольность.
# «Я б сердце: в нем всё жив и глаза,
# От их всеслышащих ушей.
# Они сиярь, и хотел он меня;
# В берегва с нахред лет;
# И в прах думает во мне,
# Есть в милой один, и Как дар
# 1115
# 1116
# 1117
# 1118
# 1119
# Loss: 0.06125553615391254
#  улышный венчанный туман;
# Но в над моей деревчела.
# Достана ты с небесной вынестобом святой,
# И без молитву чудный блеск один
# На долго живал на долге вон;
# По небесной другом свете
# Был с коложно молодая.
#
# 1120
# 1121
# 1122
# 1123
# 1124
# Loss: 0.060735302940011025
#  улышный Искатил
# Илаги соррошенный тревогда, ничего,
# Что был направно я зажи сосодишь
# Крумен юных дерский цвет во россии
# И с срадами мукимой мгла.
# Жирный сени, запала,
# Ещ темой прочей, нольме на полины
# 1125
# 1126
# 1127
# 1128
# 1129
# Loss: 0.06068178340792656
#  улышный в сердце в тесно.
# Под ним веселый думать
# Он солами наслаждется,
# Я сердит и человьких
# Во стремоте песни, коварной,
# Как бы под ними темно; и младогля иль померь
# Не она взор и видеть,
# Он довольно
# 1130
# 1131
# 1132
# 1133
# 1134
# Loss: 0.060647926554083825
#  улышный в сердце в тесно.
# Под ним веселый думать в перед тела.
# Пень одная разговор веселый не не спанию:
# Нет ей долина и пловки?
# Милый зада я на дорогу
# Пред собой с холодной в небесной
# ...
# Свобою в ней деревне ладов,
# Он
# 1685
# 1686
# 1687
# 1688
# 1689
# Loss: 0.054983924329280856
#  улышный в сердце в тесно.
# Под ним веселый думать в перед залая
# И сердце в будет и клеки,
# Размерущеньями и странной
# И в степь укатился, но там
# При всему безмолвно не смиртенье
# Вскрик молодой старине.
# Н
# 1690
# 1691
# 1692
# 1693
# 1694
# Loss: 0.05466912880539894
#  улышный в сердце в тесно.
# Под ним веселые простоты любимой
# Не долина и клески верною простить ее.
# И так я вад со всех милой состана
# Подконных друг друга степей
# Его воскресли вняхли обольностью;
# За бор
# 1695
# 1696
# 1697
# 1698
# 1699
# Loss: 0.054949067533016205
#  у, ее,
# И песни, как думай. Перотов,
# И сердце грусть томит, что она,
# Покрыв семью смущие завотил
# Мечтыгной нас водю:
# Ктых першей думал;
# На тем простолит я, ни везде,
# Как веселее он бесплодной гробница.
# 1700
# 1701
# 1702
# 1703
# 1704
# Loss: 0.0550618115067482
#  у, ее,
# И песни, как думай. Перотов,
# И сердце грусть лелеет
# Одна в их местью роковой
# Не наше вершине снежной
# Румянец гаснет; встал туман…
# Прибавил шагу караван.
# Посарить он и позднеймает на просторе».
#
# 1705
# 1706
# 1707
# 1708
# 1709
# Loss: 0.05490714259445667
#  улышный в сердце в тесно.
# Под ним веселый думать в перед тела;
# И не ж тебя тебя слов деньыми,
# Не знала в сердце девый мир
# Прицавно соней волной
# Их вдали хранят. Встобою думой,
# Как без волностью красов
# 1710
# 1711
# 1712
# 1713
# 1714
# Loss: 0.05473201431334019
#  улышный Искатил;
# Когда с печально вечерний стан;
# Не знаешь, долго и него
# За нуженной гровой;
# Ты так горд, и потесиль души, —
# Наружно споте имело,
# Что коня, весной мир?
# И ж день веселья, верь, на неем
# 1715
# 1716
# 1717
# 1718
# 1719
# Loss: 0.055202357620000836
#  улышный в сердце в тесно.
# Под ним веселый думать в перед тела.
# Пенья через пороги кратась.
# Есть реки без поются ебе,
# Не то долго понею нолами
# Чержал я него и блистает молны,
# И рукой не знаю караван.
# П
# 1720
# 1721
# 1722
# 1723
# 1724
# Loss: 0.054744171053171156
#  улышный в сердце в тесно.
# Под ним веселый думать в перед, —
# Мечтай знак бог ансли в дорог.
# Полод над себе я на дорогу
# Образок святой:
# Ты его, моляся богу,
# Ставь перед собой;
# Да, готовясь в бой опасный
# 1725
# 1726
# 1727
# 1728
# 1729
# Loss: 0.054427069500088694
#  улышный Исказа,
# Помни ларами полны вынесточивый
# Лишь там себе не умели, —
# Наслаял на кровью искумать.
# И под полчали кровь и вдохновенья
# Трепеща радостно в восторгах умиленья.
# Вот счастье! вот права…
# С
# 1730
# 1731
# 1732
# 1733
# 1734
# Loss: 0.0550717318803072
#  улышный в сердце в тесно.
# Под ним веселый думать в перед любез.
# Вот с царицей молодой;
# Там царица забыв, в тений стон вольбой,
# Мильчиты гордый стон глубь мой стремленье.
# Зародге нам лес и воле,
# Прогля
# 1735
# 1736
# 1737
# 1738
# 1739
# Loss: 0.05506232224404812
#  улышный в сердце в тесно.
# Под ним веселый думать в перед тела.
# Пень улыбула, как длял.
# Весто вино, как беден,
# Не внима в соне природа облаками
# На человенный обладул
# И сердце, под собое поляны
# Шелеет л
# 1740
# 1741
# 1742
# 1743
# 1744
# Loss: 0.054866884723305705
#  улышный в сердце в тесно.
# Под ним веселый думать в перед тела;
# И не ж тебя любить, мне сердце целый вений,
# И так поле на вас бежала.
# Быт вошки берегай, догда не могу властенить
# С истомите нашей все те
# 1745
# 1746
# 1747
# 1748
# 1749
# Loss: 0.05505654290318489
#  улышный в сердце в тесно.
# Под ним веселый думать
# Он собой нас отленец.
# Под тругу с небесненной видел
# Могильной меня взглятель ни веркого лаская нетей
# Да моей за могли, не походит;
# Зависть холодной вер
# 1750
# 1751
# 1752
# 1753
# 1754
# Loss: 0.05479395687580109
#  улышный в сердце в тесно.
# Под ним веселый думать в перед тела.
# Пень улыбула, как дами полны вечною,
# И за мне, кудений высоких полнок,
# Кругом я поле дальнее глядит,
# Ночным подернутое паром.
# Его молоден
# 1755
# 1756
# 1757
# 1758
# 1759
# Loss: 0.055125852450728416
#  улышный в сердце в тесно.
# Под ним веселый думать в перед тела;
# И не ж тебя любить, мне сердце целый вений,
# И так пожать горькими одиноко
# На поле пожелтели томнись:
# Я не родиной сладот судьбе.
# Млене св
# 1760
# 1761
# 1762
# 1763
# 1764
# Loss: 0.054806356132030484
#  улышный в сердце в тесно.
# Под ним веселые простоты любимой
# С стоил старик, испугался,
# С тоской томитьсной и стекла;
# И праздная с над страстнаю теперем нет…
# Трежин — на вечен волной грудь.
# И на тебя б
# 1765
# 1766
# 1767
# 1768
# 1769
# Loss: 0.05495326235890388
#  улышный в сердце в техой
# Услым насенную над поля,
# храсная размой душой
# Его несующей старич,
# Как ведто с небесною лире
# Мы сердце пределам так лета,
# Темный огненье красые,
# И долго славы внимаешь деть.
# И
# 1770
# 1771
# 1772
# 1773
# 1774
# Loss: 0.054598434343934056
#  улышный в сердце в тесно.
# Под ним веселый думать в перед тела.
# Пень улыбула, как лМелов, — но иль постог ночный
# Глядел был е окно,
# Своей не золучить нагров,
# Я князяли отставой,
# Как с тобой золотою нол
# 1775
# 1776
# 1777
# 1778
# 1779
# Loss: 0.05466521739959717
#  улышный в сердце в тесно.
# Под ним веселый думать в перед тела.
# Пень одна царевною родного вечерний стан;
# Не озвалекаяся горделивый…
# Под ним верно сете вольность;
# И в немом сё солнце от признила
# Колова
# 1780
# 1781
# 1782
# 1783
# 1784
# Loss: 0.05495563261210919
#  авцан цара
# С друг сердье жадную мечтам.
# В тех полет набыл — да к не любухи
# Мой мне в ней нас тебя мне.
# Зачем ты не сердительный путь:
# Тоска, предчувствия, заботы
# Теснят твою всечасно грудь.
# То чудится
# 1785
# 1786
# 1787
# 1788
# 1789
# Loss: 0.05503045372664928
#  улышный в сердце в тесно.
# Под ним веселый думать в перед, —
# Мечтай знак бог ансли в дорог;
# Заруч верс, деревою гора,
# В душенье проя долгам и молодая;
# Там душе нее водой,
# Клянлеч он и привек, ничьницы
# 1790
# 1791
# 1792
# 1793
# 1794
# Loss: 0.05449618324637413
#  улышный Исказа,
# Помни с бамкой слубама
# Со всей вселее долгим взором:
# Таинственным я занят разговором,
# Но не с тобой я сердцем говорю.
#
# Я говорю с подругой юных дней,
# В твоих чертах ищу черты другие,
# В
# 1795
# 1796
# 1797
# 1798
# 1799
# Loss: 0.05496282905340195
#  улышный в сердце в тесно.
# Под ним веселый думать в перед тела.
# Пень улыбула, как девица
# Я менчанный врагов
# Достую розий полный звук не лишь видите
# По ль на кому тебе от он,
# Доходней смиренья на времен
# 1800
# 1801
# 1802
# 1803
# 1804
# Loss: 0.05476934738457203
#  улышный в сердце в тесно.
# Под ним веселый думая на просторе».
# Воротился старик ко старухе,
# Рассказал ей великое чудо.
# «Я сегодня поймал было рыбку,
# Золотую рыбку, не простую;
# По-нашему говорила рыбка,
# 1805
# 1806
# 1807
# 1808
# 1809
# Loss: 0.054893932342529296
#  улышный в сердце в тесно.
# Под ним веселый думать в перед, —
# Между томли нас водит,
# И звонкий голос берегов.
# Я в нем его ль через лобма;
# И в радомрость и к признанья и все друг:
# «Свет, меня мглою склод
# 1810
# 1811
# 1812
# 1813
# 1814
# Loss: 0.05522768072783947
#  улышный в сердце в тесно.
# Под ним веселый думать
# Он солами жили спяте!
# Но полный любовь тьмы — взла молчаньем
# Он пара. Парамен. Нанив,
# Густой нивобравися Тесерем, —
# Наша нет безабвенья!
# Покрыва обид у
# 1815
# 1816
# 1817
# 1818
# 1819
# Loss: 0.05489140681922436
#  улышный в сердце в тесно.
# Под ним вений старие, везде,
# Как в гребря весной бесполесь,
# И слезы льет, и хотел он челу
# Кто же вечер у целом чувствую,
# И долго сладостной картиной
# Он любовался — и мечты
# О
# 1820
# 1821
# 1822
# 1823
# 1824
# Loss: 0.05497058294713497
#  улышный в сердце в тесно.
# Под ним веселые простоты любимой
# С стоил старик, испугался,
# С уром умною мне и без цели,
# Как пир на празднике чужом.
# К добру и злу постыдно равнодушны,
# В начале поприща мы вя
# 1825
# 1826
# 1827
# 1828
# 1829
# Loss: 0.05485527761280537
#  улышный в сердце в тесно.
# Под ним веселый думать в перед,
# Страницы злобы и порока.
# Провозглашать я стал любви
# И правды чистые ученья —
# В меня все ближние мои
# Бросали бешено каменья.
# Посыпал пеплом я г
# 1830
# 1831
# 1832
# 1833
# 1834
# Loss: 0.05531569004058838
#  улышный в сердце в тесно.
# Под ним веселый думать в перед тела.
# Пень улыбула, как дах тучить презира;
# Под видел согда, на изины волны,
# И звездой и целы, дале — на тебе сладкий голосок!
# На светлицы реск
# 1835
# 1836
# 1837
# 1838
# 1839
# Loss: 0.05503913745284081
#  улышный в сердце в тесно.
# Под ним веселый думать в перед тебе
# Летнокихла с царей, —
# Сей в страшии снег воздруг,
# Пристань, вешанный на просторе.
# Не думать, будут слышит —
# И влажный взор ее блестит
# Из-п
# 1840
# 1841
# 1842
# 1843
# 1844
# Loss: 0.05522188864648342
#  улышный в сердце в тесно.
# Под ним веселый думать в сердцу ты замени,
# Дохода, прежней лемнов следа
# Про стремела я него долго месяц
# Ее, страдал скользил подлунном стиданей
# Как верь миру ль яет;
# Где спря
# 1845
# 1846
# 1847
# 1848
# 1849
# Loss: 0.055377013757824896
#  улышный в сердце в тесно.
# Под ним веселый думать в перед тела.
# Пень улыбула, как дах тучить презира;
# Под видеть вас укор он забара
# Непревол постой-тестяяет;
# И в другом затилися нивал
# В последним она б
# 1850
# 1851
# 1852
# 1853
# 1854
# Loss: 0.05497350461781025
#  улышный в сердце в тесно.
# Под ним веселый думать в перед,
# Страницы злобы и порока.
# Провозглашать я стал любви
# И правды чистые ученья —
# В меня все ближние мои
# Бросали бешено каменья.
# Посыпал пеплом я г
# 1855
# 1856
# 1857
# 1858
# 1859
# Loss: 0.05526812955737114
#  улышный в сердце в тесно.
# Под ним веселый думать в перед тебе
# Хоть челов с холодным вниманьем вокруг, –
# Такая пустая и глупая шутка…
# Везде на просторе другого
# Одна в нем своей,
# Царь время на состана.
#
# 1860
# 1861
# 1862
# 1863
# 1864
# Loss: 0.0552281641960144
#  улышный в сердце в тесно.
# Под ним веселый думать в перед тела.
# Пень одна век, думай, что еще не бежит!
# И с ней жизни со мною золотой.
# Путьте верот святой:
# Ты под окном своей светлицы
# Горюешь, будто на
# 1865
# 1866
# 1867
# 1868
# 1869
# Loss: 0.054853005483746525
#  улышный в сердце в тесно.
# Под ним веселый думать в перед, —
# Между томли нас водит,
# И звонкий голос берегов.
# Попила сном, и ней взоры
# Нав он: «Я б селаю и благодаренный,
# И дикую еще молодой
# И целой обо
# 1870
# 1871
# 1872
# 1873
# 1874
# Loss: 0.055258873924613
#  улышный в сердце в тесно.
# Под ним вений стройство своим
# Три себя ли завесть ветер
# Окажденье скучно и просторе
# На невеста мечты, будто бури,
# И я замли леза ночь и следа
# Облаков неуловимых
# Волокнистые с
# 1875
# 1876
# 1877
# 1878
# 1879
# Loss: 0.054579800814390185
#  улышный в сердце в тесно.
# Под ним веселый думать в перед,
# Страницы змея весь серви,
# Бывули мы не законец
# Оботить лешей бежит,
# Он холодой просит лишь ветер,
# Брови трихой делать свой страсти,
# Горевна св
# 1880
# 1881
# 1882
# 1883
# 1884
# Loss: 0.05480165727436542
#  улышный в сердце в небесной
# Всегда ее в окном поле.
# Она привыкла к резвой воле,
# Она придет; но вот уж ночь,
# И скоро месяц уж покинет
# Небес далеких облака, —
# Земфиры нет как нет; и стынет
# Убогий ужин с
# 1885
# 1886
# 1887
# 1888
# 1889
# Loss: 0.0546866449713707
#  улышный в сердце в тесно.
# Под ним веселый думать
# Он сочущию потому,
# Встай ухода одиноко;
# И доглево не молясь рыбкой молит!
# Как вевело ты, ко-нет казакой?
# В наш век восповалит отверствует,
# И тоск не пр
# 1890
# 1891
# 1892
# 1893
# 1894
# Loss: 0.0542116891592741
#  улышный в сердце в тесно.
# Под ним веселый думать в перед изменилин
# Не вдруг они мечтам.
# Вогаты над речь. И мень, дубит;
# Ничтожной сиять ропа,
# И перед улабе насесния ветром,
# И на касались в бою:
# Спи, м
# 1895
# 1896
# 1897
# 1898
# 1899
# Loss: 0.05500623062252998
#  улышный в сердце в тесно.
# Под ним веселый думать
# Он собой нас отчиного видно.
# И ветвя восмотрит в разгустом молодой,
# Смилистую радостно в весенем всё и простертья твоею,
# Гроб небеса холодные поляны,
# С
# 1900
# 1901
# 1902
# 1903
# 1904
# Loss: 0.05485438339412212
#  улышный в сердце в тесно.
# Под ним веселый думать в перед тела;
# И не ж тебя его над меня,
# Как ситал нивой проляженный ночей
# Все куда навеки муки, и всё там ничтожно…
# Что страсти? — ведь рано иль поздно
# 1905
# 1906
# 1907
# 1908
# 1909
# Loss: 0.054660314545035366
#  улышный в сердце в тесно.
# Под ним веселый думать в перед,
# Страницы змея, и лезами,
# На другом солнце остаупи,
# Была была б томман;
# Он все через порогы я главы
# За радость вопрос;
# С розный говорит одиноко
# 1910
# 1911
# 1912
# 1913
# 1914
# Loss: 0.05490701012313366
#  улышный в сердце в тесно.
# Под ним веселые простоты любимой
# С стоил старик, испугался,
# С тоской томитьсною жених изумруцный
# На кровле так некогда у него доволен,
# Люблю ее снега; в присутствии луны
# Как
# 1915
# 1916
# 1917
# 1918
# 1919
# Loss: 0.05512185908854008
#  улышный в сердце в тесно.
# Под ним веселый думая на просторе».
# Воротился старик ко старухе,
# Рассказал ей великое чудо.
# «Я сегодня поймал было рыбку,
# Золотую рыбку, не простую;
# По-нашему говорила рыбка,
# 1920
# 1921
# 1922
# 1923
# 1924
# Loss: 0.05561661325395107
#  улышный в сердце в тесно.
# Под ним веселый думать в перед тела.
# Пень одная разговор веселый не не спанию.
# Но я и мило студет меня от блести?
# Или мешей вновесть вокровьм и народу,
# Всех дорога может, ник
# 1925
# 1926
# 1927
# 1928
# 1929
# Loss: 0.055315900295972824
#  улышный в сердце в тесно.
# Под ним веселый думать в перед тела;
# И не горит огне воздей,
# Тот за водой прекрасных
# Чредой из вод выходят ясных,
# И с ними дядька их морской;
# Там королевич мимоходом
# Пленяет
# 1930
# 1931
# 1932
# 1933
# 1934
# Loss: 0.054859191849827765
#  улышный в сердце в техой
# Услым насенную над поля,
# Кудая падет, и жажды ими люблю,
# Не улеют ого лира простоты,
# Что если б Демон, пролетая,
# В то время на нее взглянул,
# То, прежних братии вспоминая,
# Он о
# 1935
# 1936
# 1937
# 1938
# 1939
# Loss: 0.05509788438677788
#  улышный в сердце в тесно.
# Под ним веселый думать
# Он солами наслаждется,
# Я сердит и давно пора!
# Станутой селов порочь,
# Что я не оставил, и все,
# Красавами молиться где для него горя
# И в крут мудром, нев
# 1940
# 1941
# 1942
# 1943
# 1944
# Loss: 0.054875316247344014
#  улышный в сердце в тесно.
# Под ним веселый думать в перед залая
# Пред сердце свет он и покое;
# Он в стране далекой внинул — пал,
# При веселым презрели нет,
# Дай ей чела. Песинавля в дороги,
# Вослотил своим
# 1945
# 1946
# 1947
# 1948
# 1949
# Loss: 0.05488677121698857
#  улышный в сердце в тесно.
# Под ним веселый думать в перед тела.
# Пень улыбула, как дах тоскою
# От их всевидящего глаза,
# От их всеслышащих ушей.
# Спродину своей светлицы стеснены.
# Суровою зимой я более дов
# 1950
# 1951
# 1952
# 1953
# 1954
# Loss: 0.05554647140204907
#  улышный в сердце в тесно.
# Под ним веселый думать
# Он сочущию поле новой
# Над требой от она челее век волной
# И синовить лет сама и странной.
# Пришел подетной темно,
# Как немла до с вудном гордели,
# Счасталс
# 1955
# 1956
# 1957
# 1958
# 1959
# Loss: 0.05473607294261455
#  улышный в сердце в тесно.
# Под ним веселый думать в перед тела;
# И не ж друживое довагую,
# Спи е ночь, девственной тиной
# Его вад мелкомое властью люблю,
# Не для меня красы твоей блистанье;
# Люблю в тебе я
# 1960
# 1961
# 1962
# 1963
# 1964
# Loss: 0.05477040700614452
#  улышный в сердце в тесно.
# Под ним веселый думать в перед телители,
# И клет там не знаю темно, и крикова
# Невеста так бедной девали;
# Печасенья клики всеми навственных
# Скожу всё моей раз она
# С еей гело не
# 1965
# 1966
# 1967
# 1968
# 1969
# Loss: 0.055315470099449156
#  улышный Исказа,
# Помни с бамкой слубавай,
# С туданья нам его не нельзами,
# Раздвинной меж пустой,
# Ребят размушней прихоть. Всезде ближеньем
# То порыки старик седой,
# Развалин страж полуживой,
# Людьми и смер
# 1970
# 1971
# 1972
# 1973
# 1974
# Loss: 0.05493284106254578
#  улышный в сердце в тесно.
# Под ним веселый думать в перед тела.
# Пень одна вечный в ненего делить степяют.
# Как лаская словам доле,
# Не в слез на снега с мерлица,
# Тиг за дремление пропад,
# И ум слиши оспор
# 1975
# 1976
# 1977
# 1978
# 1979
# Loss: 0.05536495223641395
#  улышный в сердце в тесно.
# Под ним веселые простоты любимой
# С стоил старик, столько их дослов,
# Возру с травой морской и небы
# Долночь, как стала я нем
# Всех дороги так забрушна.
# Том тому на пирует
# Один о
# 1980
# 1981
# 1982
# 1983
# 1984
# Loss: 0.05484812773764133
#  улышный в сердце в тесно.
# Под ним веселый думать
# Он солами наслаждется,
# Я сердит и давно пора!
# Стоит склонясь, на вас богу сладких чувства лилотомлены,
# И тем правду друга добры,
# На мутной родных искуч
# 1985
# 1986
# 1987
# 1988
# 1989
# Loss: 0.05450342111289501
#  улышный в сердце в тесно.
# Под ним веселый думать в перед телиты
# И независть мы нем нет,
# Страните обеди не верам,
# Ни тайно трудом мусномитель;
# За чем, и красная сепе!
# Он не наше без целить они,
# И празд
# 1990
# 1991
# 1992
# 1993
# 1994
# Loss: 0.05489493794739246
#  улышный Искатил;
# Когда с той уверить ногави,
# Горит по влагом и мечтам.
# Вог те сердце в теснены, и лет!..
# Уграми младая полны удохнела
# Чертень намесь в пустынном поле;
# Уж с какой забавы тесни, и волны.
# 1995
# 1996
# 1997
# 1998
# 1999
# Loss: 0.0550119099766016
#  улышный в сердце в тесно.
# Под ним веселый думать в перед телители,
# И клятвы тренов славы, ни обман…
# Он песинов прибыла б я свою!..
# И Олука свободов сердца
# Моя своей скалотела.
# Я встай время на его дуб

# %%
model.eval()

print(evaluate(
    model,
    loaded_dict,
    index_to_word,
    temp=0.3,
    prediction_len=250,
    start_text='дышал как нелюдь  '
    )
)
# Out:
# дышал как нелюдь  Мостом
# Трель, коня неземных усенья но не цвету она
# В тени так зенит воздеться конь,
# Но верными руком.
# Всё пускава тений обо мгла
# На поля поэта лит; не ветвя,
# Что стол бога страстью светлый зашар,
# Когда бы ние всю славу
# Мы стол больною лебежден.
# В тел
